# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/oma21/miniconda3/envs/enm_snakemake_test1/lib/python3.10/site-packages', '/home/oma21/tmp/enm_package/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\xb7\x05\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x19data/raw/ontology/sgd.gaf\x94\x8c\x1edata/raw/ontology/go-basic.obo\x94\x8c\x1fdata/interim/go_background_list\x94\x8c"data/raw/ontology/SGD_features.tab\x94\x8c\x1bdata/interim/sensors_df.csv\x94\x8c\x1ddata/interim/effectors_df.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x03gaf\x94K\x00N\x86\x94\x8c\x03obo\x94K\x01N\x86\x94\x8c\x0fbackground_file\x94K\x02N\x86\x94\x8c\x08sgd_info\x94K\x03N\x86\x94\x8c\x0bsensors_pcc\x94K\x04N\x86\x94\x8c\x0ceffector_pcc\x94K\x05N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh!\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\')}\x94\x8c\x05_name\x94h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh\x13h\nh\x15h\x0bh\x17h\x0ch\x19h\rh\x1bh\x0eh\x1dh\x0fub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c3reports/04-Signaling-related-effector-sensors.ipynb\x94\x8c*data/interim/signaling_related_sensors.csv\x94e}\x94(h\x11}\x94(\x8c\x08notebook\x94K\x00N\x86\x94\x8c\x14sensors_signaling_df\x94K\x01N\x86\x94uh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh9h5h;h6ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94}\x94(h\x11}\x94h\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x11}\x94h\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x11}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bhlK\x01hnK\x01hphiub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c3reports/04-Signaling-related-effector-sensors.ipynb\x94a}\x94(h\x11}\x94h9K\x00N\x86\x94sh\x1f]\x94(h!h"eh!h%h\'\x85\x94R\x94(h\')}\x94h+h!sNt\x94bh"h%h\'\x85\x94R\x94(h\')}\x94h+h"sNt\x94bh9h\x7fub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x12eff_sens_signaling\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c%/home/oma21/tmp/enm_package/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/home/oma21/tmp/enm_package');
######## snakemake preamble end #########

# %%
import pandas as pd
import numpy as np
from enm.utils import *

# %%
gaf = snakemake.input['gaf']
obo = snakemake.input['obo']
background_file = snakemake.input['background_file']
sgd_info = snakemake.input['sgd_info']

goea , geneid2name , obo = create_goea(gaf = gaf, obo_fname=obo, 
                                background=background_file, sgd_info_tab = sgd_info,
                                       goset=['BP'], methods=['fdr','fdr_bh','bonferroni'])
# Out:
# data/raw/ontology/go-basic.obo: fmt(1.2) rel(2021-05-01) 47,284 GO Terms; optional_attrs(relationship)
# HMS:0:00:01.566858  41,910 annotations READ: data/raw/ontology/sgd.gaf BP
#
# Load BP Gene Ontology Analysis ...
# Propagating term counts up: is_a and negatively_regulates part_of positively_regulates regulates
# 46 GO IDs NOT FOUND IN ASSOCIATION: GO:0001300 GO:0061404 GO:1902352 GO:1900526 GO:0034225 GO:0071733 GO:1902353 GO:0072321 GO:0097236 GO:1900472 GO:0061392 GO:0090203 GO:0018065 GO:0001302 GO:1990872 GO:0035955 GO:0035961 GO:0035952 GO:0001308 GO:0061416 GO:1903474 GO:0048310 GO:1900524 GO:1900473 GO:0061427 GO:1900008 GO:1900062 GO:0090202 GO:0035969 GO:0090579 GO:0001320 GO:0000733 GO:1900525 GO:0051188 GO:1900462 GO:0001319 GO:1900466 GO:0001324 GO:0055114 GO:0061393 GO:1900465 GO:0010978 GO:0018192 GO:0035392 GO:0072363 GO:0009108
#  82%  4,649 of  5,672 population items found in association

# %%
signaling_related_gos = ['GO:0007165', 'GO:0023052','GO:0007154' ]

# %%
sensors_df = pd.read_csv(snakemake.input.sensors_pcc)

# %%
# %%capture
query_gene_ids = [key for key,value in geneid2name.items() if value in sensors_df.loc[:,'Systematic gene name'].unique()]
goea_res_all = goea.run_study(query_gene_ids)
goea_res_sig = [r for r in goea_res_all if r.p_fdr<0.1]
go_df_sensor = goea_to_pandas(goea_res_sig, geneid2name)
# Out:
# Run BP Gene Ontology Analysis: current study set of 43 IDs ... 86%     37 of     43 study items found in association
# 100%     43 of     43 study items found in population(5672)
# Calculating 4,999 uncorrected p-values using fisher
#    4,999 GO terms are associated with  4,623 of  5,672 population items
#      696 GO terms are associated with     37 of     43 study items
#   METHOD fdr:
#       19 GO terms found significant (< 0.1=alpha) ( 19 enriched +   0 purified): local fdr
#       20 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#   METHOD fdr_bh:
#       38 GO terms found significant (< 0.1=alpha) ( 38 enriched +   0 purified): statsmodels fdr_bh
#       27 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#   METHOD bonferroni:
# ...

# %%
go_df_sensor
# Out:
#             GO  NS enrichment  \
# 0   GO:0031930  BP          e
# 1   GO:0006099  BP          e
# 2   GO:0043648  BP          e
# 3   GO:0006357  BP          e
# 4   GO:0046901  BP          e
# 5   GO:0046900  BP          e
# 6   GO:0045893  BP          e
# 7   GO:1902680  BP          e
# 8   GO:1903508  BP          e
# 9   GO:0006366  BP          e
# 10  GO:0045944  BP          e
# 11  GO:0009060  BP          e
# 12  GO:0071396  BP          e
# 13  GO:0034201  BP          e
# 14  GO:0070542  BP          e
# 15  GO:0071400  BP          e
# 16  GO:0015823  BP          e
# 17  GO:0033993  BP          e
# 18  GO:0071398  BP          e
#
#                                                  name ratio_in_study  \
# 0              mitochondria-nucleus signaling pathway        (4, 43)
# 1                            tricarboxylic acid cycle        (5, 43)
# 2                 dicarboxylic acid metabolic process        (5, 43)
# ...

# %%
sensor_signaling_go = [i for i in goea_res_all if i.GO in signaling_related_gos]

# %%
sgd_desc = pd.read_csv(snakemake.input.sgd_info,'\t',header=None)

# %%
(sensors_df
    .loc[sensors_df['Systematic gene name'].isin([*[geneid2name[i] for i in sensor_signaling_go[0].study_items],*['YCL025C','YDR463W','YHR006W','YBR068C']])]
    .loc[:,['orf_name','Systematic gene name','go_group','label']].reset_index(drop=True)
    .merge(sgd_desc.loc[:,[3,15]],left_on='Systematic gene name',right_on = 3).rename(columns={15:'Description'})
    .drop(labels=3,axis=1)
    .to_csv(snakemake.output.sensors_signaling_df))

# %%
effectors_df =pd.read_csv(snakemake.input.effector_pcc)

# %%
# %%capture
query_gene_ids = [key for key,value in geneid2name.items() if value in effectors_df.loc[:,'Systematic gene name'].unique()]
goea_res_all_eff = goea.run_study(query_gene_ids)
goea_res_sig_eff = [r for r in goea_res_all_eff if r.p_fdr<0.1]
go_df_effector = goea_to_pandas(goea_res_sig_eff, geneid2name)
# Out:
# Run BP Gene Ontology Analysis: current study set of 48 IDs ...100%     48 of     48 study items found in association
# 100%     48 of     48 study items found in population(5672)
# Calculating 4,999 uncorrected p-values using fisher
#    4,999 GO terms are associated with  4,623 of  5,672 population items
#      711 GO terms are associated with     48 of     48 study items
#   METHOD fdr:
#       45 GO terms found significant (< 0.1=alpha) ( 45 enriched +   0 purified): local fdr
#       48 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#   METHOD fdr_bh:
#       74 GO terms found significant (< 0.1=alpha) ( 74 enriched +   0 purified): statsmodels fdr_bh
#       48 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
#   METHOD bonferroni:
# ...

# %%
eff_go_sig = [i for i in goea_res_all_eff if i.GO in signaling_related_gos]#[0]

# %%
(effectors_df
    .loc[effectors_df['Systematic gene name'].isin([geneid2name[i] for i in eff_go_sig[0].study_items])]
     .loc[:,['orf_name','Systematic gene name','go_group','effector_cluster']].reset_index(drop=True)
    .merge(sgd_desc.loc[:,[3,15]],left_on='Systematic gene name',right_on = 3).rename(columns={15:'Description'})
    .drop(labels=3,axis=1))
# Out:
#   orf_name Systematic gene name                             go_group  \
# 0     csm3              YMR048W          replication fork protection
# 1     mad1              YGL086W          replication fork protection
# 2     mad2              YJL030W          replication fork protection
# 3     mrc1              YCL061C          replication fork protection
# 4     tof1              YNL273W          replication fork protection
# 5   ypt1-3              YFL038C  membrane lipid biosynthetic process
#
#    effector_cluster                                        Description
# 0                 1  Replication fork associated factor; required f...
# 1                 1  Coiled-coil protein involved in spindle-assemb...
# 2                 1  Component of the spindle-assembly checkpoint c...
# 3                 1  S-phase checkpoint protein required for DNA re...
# 4                 1  Subunit of a replication-pausing checkpoint co...
# ...
