# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/oma21/miniconda3/envs/enm_snakemake_test1/lib/python3.10/site-packages', '/home/oma21/tmp/enm_package/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95j\x06\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x19data/raw/ontology/sgd.gaf\x94\x8c\x1edata/raw/ontology/go-basic.obo\x94\x8c\x1fdata/interim/go_background_list\x94\x8c"data/raw/ontology/SGD_features.tab\x94\x8c\x17data/interim/pcc.pickle\x94\x8c\x1bdata/interim/sensors_df.csv\x94\x8c\x1ddata/interim/effectors_df.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x03gaf\x94K\x00N\x86\x94\x8c\x03obo\x94K\x01N\x86\x94\x8c\x0fbackground_file\x94K\x02N\x86\x94\x8c\x08sgd_info\x94K\x03N\x86\x94\x8c\x10pickle_file_name\x94K\x04N\x86\x94\x8c\x0bsensors_pcc\x94K\x05N\x86\x94\x8c\x0ceffector_pcc\x94K\x06N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh$\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h*)}\x94\x8c\x05_name\x94h$sNt\x94bh%h(h*\x85\x94R\x94(h*)}\x94h.h%sNt\x94bh\x14h\nh\x16h\x0bh\x18h\x0ch\x1ah\rh\x1ch\x0eh\x1eh\x0fh h\x10ub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c\x1ereports/08-Fig5abc_figs5.ipynb\x94\x8c\x1fdata/interim/eff_sens_path1.csv\x94\x8c\x1fdata/interim/eff_sens_path2.csv\x94\x8c\x1fdata/interim/eff_sens_path3.csv\x94\x8c/data/interim/eff_sens_combined_for_coloring.csv\x94e}\x94(h\x12}\x94(\x8c\x08notebook\x94K\x00N\x86\x94\x8c\x03ec1\x94K\x01N\x86\x94\x8c\x03ec2\x94K\x02N\x86\x94\x8c\x03ec3\x94K\x03N\x86\x94\x8c\x18combined_data_for_colors\x94K\x04N\x86\x94uh"]\x94(h$h%eh$h(h*\x85\x94R\x94(h*)}\x94h.h$sNt\x94bh%h(h*\x85\x94R\x94(h*)}\x94h.h%sNt\x94bh?h8hAh9hCh:hEh;hGh<ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94\x88a}\x94(h\x12}\x94\x8c\x04save\x94K\x00N\x86\x94sh"]\x94(h$h%eh$h(h*\x85\x94R\x94(h*)}\x94h.h$sNt\x94bh%h(h*\x85\x94R\x94(h*)}\x94h.h%sNt\x94bhX\x88ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\x12}\x94h"]\x94(h$h%eh$h(h*\x85\x94R\x94(h*)}\x94h.h$sNt\x94bh%h(h*\x85\x94R\x94(h*)}\x94h.h%sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94e}\x94(h\x12}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh"]\x94(h$h%eh$h(h*\x85\x94R\x94(h*)}\x94h.h$sNt\x94bh%h(h*\x85\x94R\x94(h*)}\x94h.h%sNt\x94bhzK\x01h|K\x01h~hwub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c\x1ereports/08-Fig5abc_figs5.ipynb\x94a}\x94(h\x12}\x94h?K\x00N\x86\x94sh"]\x94(h$h%eh$h(h*\x85\x94R\x94(h*)}\x94h.h$sNt\x94bh%h(h*\x85\x94R\x94(h*)}\x94h.h%sNt\x94bh?h\x8dub\x8c\x06config\x94}\x94\x8c\x04rule\x94\x8c\x0bfigure_5_s5\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8c%/home/oma21/tmp/enm_package/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/home/oma21/tmp/enm_package');
######## snakemake preamble end #########

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Find-all-shortest-paths-and-shortest-paths-with-highest-PRS-weight" data-toc-modified-id="Find-all-shortest-paths-and-shortest-paths-with-highest-PRS-weight-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Find all shortest paths and shortest paths with highest PRS weight</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Fig-S5A" data-toc-modified-id="Fig-S5A-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Fig S5A</a></span></li></ul></li></ul></li><li><span><a href="#Calculate-GO-enrichment-of-paths-using-only-the-genes-on-the-path-(excl.-effector-and-sensor)" data-toc-modified-id="Calculate-GO-enrichment-of-paths-using-only-the-genes-on-the-path-(excl.-effector-and-sensor)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Calculate GO enrichment of paths using only the genes on the path (excl. effector and sensor)</a></span></li></ul></div>

# %%
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import matplotlib as mpl
import networkx as nx
import numpy as np
import pandas as pd
import pickle
import os
import re
import itertools as itr
import matplotlib as mpl
import seaborn as sns
from enm.Enm import Enm
from enm.utils import *
from tqdm import tqdm

# %%
with open(snakemake.input.pickle_file_name , 'rb') as f:
    e_pcc = pickle.load(f)

# %%
nodes = e_pcc.nodes
n = len(nodes)

# %%
effectors_df = pd.read_csv(snakemake.input.effector_pcc)

# %%
sensors_df = pd.read_csv(snakemake.input.sensors_pcc)

# %% [markdown]
# # Find all shortest paths and shortest paths with highest PRS weight

# %%
def find_all_shortest_paths(sources, targets, g):
    paths = []
    counts = []
    for s in sources.orf_name.tolist():
        w_track=0
        for t in targets.orf_name.tolist():
            p = list(nx.all_shortest_paths(g, s, t))
#            counts.append(len(p))
#            p_weights = [prs_mat_df.loc[s,pp].sum() for pp in p]
            paths.extend(p)
    #
    shortest_paths = [i for i in paths if len(i) == np.min([len(uu) for uu in paths])]
    #path_weights = [prs_mat_df.loc[pp[0],pp].sum() for pp in shortest_paths]
    return shortest_paths#[np.argmax(path_weights)], counts 
#    return paths

# %%
def find_highest_prs_path(sources, targets, g, prs_mat_df):
    paths = []
    counts = []
    for s in sources.orf_name.tolist():
        w_track=0
        for t in targets.orf_name.tolist():
            p = list(nx.all_shortest_paths(g, s, t))
            counts.append(len(p))
            p_weights = [prs_mat_df.loc[s,pp].sum() for pp in p]
            paths.append(p[np.argmax(p_weights)])
    #
    shortest_paths = [i for i in paths if len(i) == np.min([len(uu) for uu in paths])]
    path_weights = [prs_mat_df.loc[pp[0],pp].sum() for pp in shortest_paths]
    return shortest_paths[np.argmax(path_weights)], counts 
#    return paths

# %%
all_paths = {0:{} , 1:{}, 2:{}}
all_path_counts ={0:{} , 1:{}, 2:{}}

# %%
all_shortest_paths = {0:{},1:{},2:{}}

# %%
#counts = []
for i in range(3):
    sources = effectors_df.loc[effectors_df.effector_cluster==i]
    for j in np.arange(1,10):
        targets = sensors_df.loc[sensors_df.gid==j]
        p= find_all_shortest_paths(sources, targets,e_pcc.graph_gc)
        all_shortest_paths[i][j]=p
        #all_path_counts[i][j] = c
        #counts.append(c)

# %%
all_shortest_paths_counts = np.zeros((3,10))

# %%
for i in range(3):
    for j in range(1,10):
        c = len(all_shortest_paths[i][j])
        all_shortest_paths_counts[i][j] = c

# %%
np.set_printoptions(suppress=True)
all_shortest_paths_counts
# Out:
# array([[   0.,   28.,   16.,   78.,    1.,   40.,   14.,   78.,    1.,
#            5.],
#        [   0.,   16.,   16., 4089.,    3.,   18.,    1.,    3.,    4.,
#           11.],
#        [   0.,    3.,  196.,   51.,    6.,   14.,   16.,   11.,   52.,
#           44.]])

# %% [markdown]
# Total shortest paths between effector and sensor clusters

# %% [markdown]
# ### Fig S5A

# %%
fig, ax = plt.subplots(figsize=(7,2.5))
sns.heatmap(pd.DataFrame(all_shortest_paths_counts[:,1:],index=['EC1','EC2','EC3'],columns=[f"SC{i}" for i in range(1,10)]),
           annot=True, ax = ax, fmt='.0f',linewidths=.5, cmap='Blues',cbar_kws={"orientation": "horizontal"})
plt.yticks(rotation=0) 
if snakemake.params.save:
    fig.savefig('reports/figures/paper_figures_supp/figs6_a.png',dpi=150, bbox_inches='tight')

# %%
all_shortest_paths_counts.sum()
# Out:
# 4815.0

# %% [markdown]
# # Calculate GO enrichment of paths using only the genes on the path (excl. effector and sensor)

# %%
# %%capture
gaf = snakemake.input['gaf']
obo = snakemake.input['obo']
background_file = snakemake.input['background_file']
sgd_info = snakemake.input['sgd_info']
pickle_file = snakemake.input['pickle_file_name']
goea, geneid2name, _ = create_goea(gaf = gaf, obo_fname=obo, 
                                background=background_file, sgd_info_tab = sgd_info)
# Out:
# data/raw/ontology/go-basic.obo: fmt(1.2) rel(2021-05-01) 47,284 GO Terms; optional_attrs(relationship)
# Propagating term counts up: is_a and negatively_regulates part_of positively_regulates regulates

# %%
counts = []
for i in range(3):
    sources = effectors_df.loc[effectors_df.effector_cluster==i]
    for j in np.arange(1,10):
        targets = sensors_df.loc[sensors_df.gid==j]
        p,c = find_highest_prs_path(sources, targets,e_pcc.graph_gc, e_pcc.prs_mat_df)
        all_paths[i][j]=p
        all_path_counts[i][j] = c
        #counts.append(c)

# %%
#%%capture
goa_go_dict = {0:{},1:{},2:{}}
for i in range(3):
    #sources = effectors_df.loc[effectors_df.effector_cluster==i]
    for j in np.arange(1,10):
        #targets = sensors_df.loc[sensors_df.gid==j]
        p= all_paths[i][j]
        p_sub = p[1:-1]
        p_sub_df = e_pcc.df.loc[e_pcc.df.orf_name.isin(p_sub)]
        go_res = query_goatools(p_sub_df, goea,geneid2name)
        goa_go_dict[i][j] = go_res
        ##all_shortest_paths[i][j]=p
        
        #all_path_counts[i][j] = c
        #counts.append(c)
# Out:
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0010576413937897666
# Sample 10 / 500: p-value 0.0015861823243049813
# Sample 20 / 500: p-value 0.008440257891505177
# Sample 30 / 500: p-value 0.0005289139633310729
# Sample 40 / 500: p-value 0.011068065081199145
# Sample 50 / 500: p-value 0.004226090628537098
# Sample 60 / 500: p-value 0.0005289139633310729
# Sample 70 / 500: p-value 0.0026427048169141362
# Sample 80 / 500: p-value 0.0026427048169141362
# Sample 90 / 500: p-value 0.0005289139633310729
# Sample 100 / 500: p-value 0.0015861823243049813
# Sample 110 / 500: p-value 0.0005289139633310729
# Sample 120 / 500: p-value 0.008966191276685475
# Sample 130 / 500: p-value 0.0005289139633310729
# Sample 140 / 500: p-value 0.0036984817044686314
# Sample 150 / 500: p-value 0.0005289139633310729
# Sample 160 / 500: p-value 0.0001598494612480888
# Sample 170 / 500: p-value 0.0005289139633310729
# Sample 180 / 500: p-value 0.0026427048169141362
# Sample 190 / 500: p-value 0.0005289139633310729
# Sample 200 / 500: p-value 0.0015861823243049813
# Sample 210 / 500: p-value 0.0010576413937897666
# Sample 220 / 500: p-value 0.004226090628537098
# Sample 230 / 500: p-value 0.003170686444882702
# Sample 240 / 500: p-value 0.0005289139633310729
# Sample 250 / 500: p-value 0.0015861823243049813
# Sample 260 / 500: p-value 0.00042162443246505503
# Sample 270 / 500: p-value 0.0005289139633310729
# Sample 280 / 500: p-value 0.0005289139633310729
# Sample 290 / 500: p-value 0.013166964887276504
# Sample 300 / 500: p-value 0.0005289139633310729
# Sample 310 / 500: p-value 1
# Sample 320 / 500: p-value 0.0015861823243049813
# Sample 330 / 500: p-value 0.0005289139633310729
# Sample 340 / 500: p-value 0.08427243634412128
# Sample 350 / 500: p-value 0.0005289139633310729
# Sample 360 / 500: p-value 0.0015861823243049813
# Sample 370 / 500: p-value 0.0005289139633310729
# Sample 380 / 500: p-value 0.0015861823243049813
# Sample 390 / 500: p-value 0.0015861823243049813
# Sample 400 / 500: p-value 0.0015861823243049813
# Sample 410 / 500: p-value 0.002114536787698157
# Sample 420 / 500: p-value 0.0005289139633310729
# Sample 430 / 500: p-value 0.0005289139633310729
# Sample 440 / 500: p-value 0.0005289139633310729
# Sample 450 / 500: p-value 0.0005289139633310729
# Sample 460 / 500: p-value 0.0010576413937897666
# Sample 470 / 500: p-value 0.0005289139633310729
# Sample 480 / 500: p-value 0.007387832970063665
# Sample 490 / 500: p-value 0.0005289139633310729
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0028186366029831116
# Sample 10 / 500: p-value 0.0014100641698067402
# Sample 20 / 500: p-value 0.0035223637472303086
# Sample 30 / 500: p-value 0.001128707736058569
# Sample 40 / 500: p-value 0.0021145367877069476
# Sample 50 / 500: p-value 0.0021145367877069476
# Sample 60 / 500: p-value 0.0007052186177776944
# Sample 70 / 500: p-value 0.0014100641698067402
# Sample 80 / 500: p-value 0.0014100641698067402
# Sample 90 / 500: p-value 0.0014100641698067402
# Sample 100 / 500: p-value 0.0014100641698067402
# Sample 110 / 500: p-value 0.0014100641698067402
# Sample 120 / 500: p-value 0.0028186366029831116
# Sample 130 / 500: p-value 0.0007052186177776944
# Sample 140 / 500: p-value 0.0014100641698067402
# Sample 150 / 500: p-value 0.06735817394137722
# Sample 160 / 500: p-value 0.0028186366029831116
# Sample 170 / 500: p-value 0.0009747937312844196
# Sample 180 / 500: p-value 0.0021145367877069476
# Sample 190 / 500: p-value 0.005631310468806453
# Sample 200 / 500: p-value 0.0007052186177776944
# Sample 210 / 500: p-value 0.002272123043852676
# Sample 220 / 500: p-value 0.006333548243956442
# Sample 230 / 500: p-value 0.0014100641698067402
# Sample 240 / 500: p-value 0.0028186366029831116
# Sample 250 / 500: p-value 0.0014100641698067402
# Sample 260 / 500: p-value 0.0028186366029831116
# Sample 270 / 500: p-value 0.0035223637472303086
# Sample 280 / 500: p-value 0.0021145367877069476
# Sample 290 / 500: p-value 0.0028186366029831116
# Sample 300 / 500: p-value 0.0021145367877069476
# Sample 310 / 500: p-value 0.004225718352000553
# Sample 320 / 500: p-value 0.0007052186177776944
# Sample 330 / 500: p-value 0.0035223637472303086
# Sample 340 / 500: p-value 3.385325311875666e-05
# Sample 350 / 500: p-value 0.0028186366029831116
# Sample 360 / 500: p-value 0.0007052186177776944
# Sample 370 / 500: p-value 0.0007607363364758449
# Sample 380 / 500: p-value 0.0007052186177776944
# Sample 390 / 500: p-value 0.0007052186177776944
# Sample 400 / 500: p-value 0.0007052186177776944
# Sample 410 / 500: p-value 0.0014100641698067402
# Sample 420 / 500: p-value 0.005631310468806453
# Sample 430 / 500: p-value 0.0007052186177776944
# Sample 440 / 500: p-value 0.0028186366029831116
# Sample 450 / 500: p-value 0.0077369078847419484
# Sample 460 / 500: p-value 0.016125875420267378
# Sample 470 / 500: p-value 0.0007052186177776944
# Sample 480 / 500: p-value 0.0014100641698067402
# Sample 490 / 500: p-value 0.01682254677785595
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.007654811057041949
# Sample 10 / 500: p-value 0.004226090628537098
# Sample 20 / 500: p-value 0.0015861823243049813
# Sample 30 / 500: p-value 0.0005289139633310729
# Sample 40 / 500: p-value 0.0015861823243049813
# Sample 50 / 500: p-value 0.0015861823243049813
# Sample 60 / 500: p-value 0.0005695046680848177
# Sample 70 / 500: p-value 0.0005289139633310729
# Sample 80 / 500: p-value 1.8646707725670881e-06
# Sample 90 / 500: p-value 0.005807799716953163
# Sample 100 / 500: p-value 0.00791413846704628
# Sample 110 / 500: p-value 0.0005289139633310729
# Sample 120 / 500: p-value 0.002114536787698157
# Sample 130 / 500: p-value 0.0010576413937897666
# Sample 140 / 500: p-value 0.0010576413937897666
# Sample 150 / 500: p-value 0.005280749601815006
# Sample 160 / 500: p-value 0.0005289139633310729
# Sample 170 / 500: p-value 0.0010576413937897666
# Sample 180 / 500: p-value 0.005280749601815006
# Sample 190 / 500: p-value 0.0015861823243049813
# Sample 200 / 500: p-value 0.0005289139633310729
# Sample 210 / 500: p-value 0.0005289139633310729
# Sample 220 / 500: p-value 0.002114536787698157
# Sample 230 / 500: p-value 0.00011402849973214575
# Sample 240 / 500: p-value 0.0015861823243049813
# Sample 250 / 500: p-value 0.0005289139633310729
# Sample 260 / 500: p-value 0.00023645920333355584
# Sample 270 / 500: p-value 0.004753513249938459
# Sample 280 / 500: p-value 0.0005289139633310729
# Sample 290 / 500: p-value 0.012642518632945299
# Sample 300 / 500: p-value 0.0005289139633310729
# Sample 310 / 500: p-value 0.002114536787698157
# Sample 320 / 500: p-value 0.0010576413937897666
# Sample 330 / 500: p-value 0.0026427048169141362
# Sample 340 / 500: p-value 0.003170686444882702
# Sample 350 / 500: p-value 0.00037330893096729206
# Sample 360 / 500: p-value 0.007387832970063665
# Sample 370 / 500: p-value 1.453074636898501e-05
# Sample 380 / 500: p-value 0.0005289139633310729
# Sample 390 / 500: p-value 0.0015861823243049813
# Sample 400 / 500: p-value 0.0058611681866541955
# Sample 410 / 500: p-value 0.002114536787698157
# Sample 420 / 500: p-value 0.0005289139633310729
# Sample 430 / 500: p-value 0.0026427048169141362
# Sample 440 / 500: p-value 0.0015861823243049813
# Sample 450 / 500: p-value 0.001447529642931728
# Sample 460 / 500: p-value 0.0015861823243049813
# Sample 470 / 500: p-value 0.004577378547766057
# Sample 480 / 500: p-value 0.0005289139633310729
# Sample 490 / 500: p-value 0.005807799716953163
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.002259423907965612
# Sample 10 / 500: p-value 0.0007411794235744593
# Sample 20 / 500: p-value 0.0007052186177776944
# Sample 30 / 500: p-value 0.0014100641698067402
# Sample 40 / 500: p-value 0.0004888876295491435
# Sample 50 / 500: p-value 0.0028186366029831116
# Sample 60 / 500: p-value 0.0028186366029831116
# Sample 70 / 500: p-value 0.0014100641698067402
# Sample 80 / 500: p-value 0.0007052186177776944
# Sample 90 / 500: p-value 0.0006297912835548305
# Sample 100 / 500: p-value 0.005090344210851324
# Sample 110 / 500: p-value 0.0021145367877069476
# Sample 120 / 500: p-value 0.0007052186177776944
# Sample 130 / 500: p-value 0.002547782342761026
# Sample 140 / 500: p-value 0.0007052186177776944
# Sample 150 / 500: p-value 0.0007052186177776944
# Sample 160 / 500: p-value 0.0021145367877069476
# Sample 170 / 500: p-value 0.005631310468806453
# Sample 180 / 500: p-value 0.0017687236687925726
# Sample 190 / 500: p-value 0.0007052186177776944
# Sample 200 / 500: p-value 0.0007052186177776944
# Sample 210 / 500: p-value 0.0021145367877069476
# Sample 220 / 500: p-value 0.0007052186177776944
# Sample 230 / 500: p-value 0.0007052186177776944
# Sample 240 / 500: p-value 0.0013059908675438553
# Sample 250 / 500: p-value 0.0014100641698067402
# Sample 260 / 500: p-value 0.0007052186177776944
# Sample 270 / 500: p-value 0.0007052186177776944
# Sample 280 / 500: p-value 0.0021145367877069476
# Sample 290 / 500: p-value 0.007035414005439635
# Sample 300 / 500: p-value 0.0007052186177776944
# Sample 310 / 500: p-value 0.002272123043852676
# Sample 320 / 500: p-value 9.392014883376988e-05
# Sample 330 / 500: p-value 0.0020022341723902486
# Sample 340 / 500: p-value 0.0021145367877069476
# Sample 350 / 500: p-value 0.0007052186177776944
# Sample 360 / 500: p-value 0.0022196049120316664
# Sample 370 / 500: p-value 0.0021145367877069476
# Sample 380 / 500: p-value 0.0014100641698067402
# Sample 390 / 500: p-value 0.0035223637472303086
# Sample 400 / 500: p-value 0.004928700548726057
# Sample 410 / 500: p-value 0.0021145367877069476
# Sample 420 / 500: p-value 0.0007052186177776944
# Sample 430 / 500: p-value 0.004225718352000553
# Sample 440 / 500: p-value 0.0014100641698067402
# Sample 450 / 500: p-value 0.0021145367877069476
# Sample 460 / 500: p-value 0.0014100641698067402
# Sample 470 / 500: p-value 0.0021145367877069476
# Sample 480 / 500: p-value 0.0014100641698067402
# Sample 490 / 500: p-value 0.0007052186177776944
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0008815232722179457
# Sample 10 / 500: p-value 9.459593148791629e-05
# Sample 20 / 500: p-value 0.0008815232722179457
# Sample 30 / 500: p-value 0.0008815232722179457
# Sample 40 / 500: p-value 0.0008815232722179457
# Sample 50 / 500: p-value 0.0005506612203417743
# Sample 60 / 500: p-value 0.0026427048169126166
# Sample 70 / 500: p-value 0.0002500452143840863
# Sample 80 / 500: p-value 0.0008815232722179457
# Sample 90 / 500: p-value 0.0035223637472136427
# Sample 100 / 500: p-value 0.002742441412411871
# Sample 110 / 500: p-value 0.00028617934667104003
# Sample 120 / 500: p-value 0.0016371650806362447
# Sample 130 / 500: p-value 0.0026427048169126166
# Sample 140 / 500: p-value 0.0008815232722179457
# Sample 150 / 500: p-value 0.012284863805839978
# Sample 160 / 500: p-value 0.0061576171145983115
# Sample 170 / 500: p-value 0.0017624247681732816
# Sample 180 / 500: p-value 0.0026427048169126166
# Sample 190 / 500: p-value 0.004963600733666215
# Sample 200 / 500: p-value 0.0008100283421137795
# Sample 210 / 500: p-value 0.0017624247681732816
# Sample 220 / 500: p-value 0.0017624247681732816
# Sample 230 / 500: p-value 0.0017624247681732816
# Sample 240 / 500: p-value 0.0008815232722179457
# Sample 250 / 500: p-value 0.007076524887782497
# Sample 260 / 500: p-value 0.0017624247681732816
# Sample 270 / 500: p-value 0.0008815232722179457
# Sample 280 / 500: p-value 0.0006336072236423295
# Sample 290 / 500: p-value 0.0008815232722179457
# Sample 300 / 500: p-value 0.0005795334276863179
# Sample 310 / 500: p-value 0.003104643966311456
# Sample 320 / 500: p-value 0.0026427048169126166
# Sample 330 / 500: p-value 0.0017624247681732816
# Sample 340 / 500: p-value 0.0002500452143840863
# Sample 350 / 500: p-value 0.0026427048169126166
# Sample 360 / 500: p-value 0.0008815232722179457
# Sample 370 / 500: p-value 0.0017624247681732816
# Sample 380 / 500: p-value 0.0008815232722179457
# Sample 390 / 500: p-value 0.0035223637472136427
# Sample 400 / 500: p-value 0.0009377987768362741
# Sample 410 / 500: p-value 0.0008815232722179457
# Sample 420 / 500: p-value 0.0035223637472136427
# Sample 430 / 500: p-value 0.0026427048169126166
# Sample 440 / 500: p-value 0.0026427048169126166
# Sample 450 / 500: p-value 0.0008815232722179457
# Sample 460 / 500: p-value 0.0008815232722179457
# Sample 470 / 500: p-value 0.0008815232722179457
# Sample 480 / 500: p-value 0.0008815232722179457
# Sample 490 / 500: p-value 0.0008815232722179457
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0005289139633310729
# Sample 10 / 500: p-value 0.002114536787698157
# Sample 20 / 500: p-value 0.003170686444882702
# Sample 30 / 500: p-value 0.037091237502829943
# Sample 40 / 500: p-value 0.0010576413937897666
# Sample 50 / 500: p-value 0.0005289139633310729
# Sample 60 / 500: p-value 0.0026427048169141362
# Sample 70 / 500: p-value 0.002114536787698157
# Sample 80 / 500: p-value 0.0010576413937897666
# Sample 90 / 500: p-value 0.0036984817044686314
# Sample 100 / 500: p-value 0.0010576413937897666
# Sample 110 / 500: p-value 0.009491938655444045
# Sample 120 / 500: p-value 0.0015861823243049813
# Sample 130 / 500: p-value 0.021011387926355377
# Sample 140 / 500: p-value 0.0005289139633310729
# Sample 150 / 500: p-value 0.0015861823243049813
# Sample 160 / 500: p-value 0.0005289139633310729
# Sample 170 / 500: p-value 0.003170686444882702
# Sample 180 / 500: p-value 1
# Sample 190 / 500: p-value 0.0005289139633310729
# Sample 200 / 500: p-value 0.022054159327492582
# Sample 210 / 500: p-value 0.003170686444882702
# Sample 220 / 500: p-value 0.0005289139633310729
# Sample 230 / 500: p-value 0.0005289139633310729
# Sample 240 / 500: p-value 0.005807799716953163
# Sample 250 / 500: p-value 0.0004341587836116447
# Sample 260 / 500: p-value 0.003170686444882702
# Sample 270 / 500: p-value 0.0004597735962591067
# Sample 280 / 500: p-value 3.415558379501807e-05
# Sample 290 / 500: p-value 0.0015861823243049813
# Sample 300 / 500: p-value 0.0015861823243049813
# Sample 310 / 500: p-value 0.002114536787698157
# Sample 320 / 500: p-value 0.002114536787698157
# Sample 330 / 500: p-value 0.0005289139633310729
# Sample 340 / 500: p-value 0.007387832970063665
# Sample 350 / 500: p-value 0.0026427048169141362
# Sample 360 / 500: p-value 0.0015861823243049813
# Sample 370 / 500: p-value 0.0036984817044686314
# Sample 380 / 500: p-value 0.08526977978546567
# Sample 390 / 500: p-value 0.0003170187707962972
# Sample 400 / 500: p-value 0.0026427048169141362
# Sample 410 / 500: p-value 0.009562462030405996
# Sample 420 / 500: p-value 0.014739189321565666
# Sample 430 / 500: p-value 0.0005289139633310729
# Sample 440 / 500: p-value 0.0005289139633310729
# Sample 450 / 500: p-value 0.0015861823243049813
# Sample 460 / 500: p-value 0.0005289139633310729
# Sample 470 / 500: p-value 0.0015861823243049813
# Sample 480 / 500: p-value 0.0015170192903359054
# Sample 490 / 500: p-value 1.453074636898501e-05
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.008787292244576663
# Sample 10 / 500: p-value 0.0002678108623542104
# Sample 20 / 500: p-value 0.0008815232722179457
# Sample 30 / 500: p-value 0.0017624247681732816
# Sample 40 / 500: p-value 0.0008815232722179457
# Sample 50 / 500: p-value 7.424532282597567e-05
# Sample 60 / 500: p-value 0.0008815232722179457
# Sample 70 / 500: p-value 0.0008815232722179457
# Sample 80 / 500: p-value 0.009662612544642754
# Sample 90 / 500: p-value 0.0035223637472136427
# Sample 100 / 500: p-value 0.0035223637472136427
# Sample 110 / 500: p-value 0.002972758758837709
# Sample 120 / 500: p-value 0.0017624247681732816
# Sample 130 / 500: p-value 0.0006615332100688011
# Sample 140 / 500: p-value 0.013157712106053297
# Sample 150 / 500: p-value 0.0044014018878737494
# Sample 160 / 500: p-value 0.0008815232722179457
# Sample 170 / 500: p-value 0.0008815232722179457
# Sample 180 / 500: p-value 0.004963600733666215
# Sample 190 / 500: p-value 0.0008815232722179457
# Sample 200 / 500: p-value 0.0026427048169126166
# Sample 210 / 500: p-value 0.0008815232722179457
# Sample 220 / 500: p-value 0.0008815232722179457
# Sample 230 / 500: p-value 0.011411397997474095
# Sample 240 / 500: p-value 0.0026427048169126166
# Sample 250 / 500: p-value 0.0035223637472136427
# Sample 260 / 500: p-value 0.0008815232722179457
# Sample 270 / 500: p-value 0.0044014018878737494
# Sample 280 / 500: p-value 0.0016371650806362447
# Sample 290 / 500: p-value 0.0044014018878737494
# Sample 300 / 500: p-value 6.211184554190044e-06
# Sample 310 / 500: p-value 0.0017624247681732816
# Sample 320 / 500: p-value 0.0017624247681732816
# Sample 330 / 500: p-value 0.0007791494274388313
# Sample 340 / 500: p-value 0.027039570610608077
# Sample 350 / 500: p-value 0.0035223637472136427
# Sample 360 / 500: p-value 0.020985612917013473
# Sample 370 / 500: p-value 0.0044014018878737494
# Sample 380 / 500: p-value 0.00045475165430675237
# Sample 390 / 500: p-value 0.0008815232722179457
# Sample 400 / 500: p-value 0.0026427048169126166
# Sample 410 / 500: p-value 0.0008815232722179457
# Sample 420 / 500: p-value 0.0017624247681732816
# Sample 430 / 500: p-value 0.001507845269656478
# Sample 440 / 500: p-value 0.0008815232722179457
# Sample 450 / 500: p-value 0.005279819567536947
# Sample 460 / 500: p-value 0.0070347948577213215
# Sample 470 / 500: p-value 0.0026427048169126166
# Sample 480 / 500: p-value 0.0015503761631097842
# Sample 490 / 500: p-value 0.0008815232722179457
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0007052186177776944
# Sample 10 / 500: p-value 0.0014100641698067402
# Sample 20 / 500: p-value 0.0021145367877069476
# Sample 30 / 500: p-value 0.0007052186177776944
# Sample 40 / 500: p-value 0.0014100641698067402
# Sample 50 / 500: p-value 0.0007052186177776944
# Sample 60 / 500: p-value 0.0035223637472303086
# Sample 70 / 500: p-value 0.0007052186177776944
# Sample 80 / 500: p-value 0.0007052186177776944
# Sample 90 / 500: p-value 0.0021145367877069476
# Sample 100 / 500: p-value 0.02030035551102239
# Sample 110 / 500: p-value 0.0028186366029831116
# Sample 120 / 500: p-value 0.0014100641698067402
# Sample 130 / 500: p-value 0.0007052186177776944
# Sample 140 / 500: p-value 0.0028186366029831116
# Sample 150 / 500: p-value 0.0014100641698067402
# Sample 160 / 500: p-value 2.4564472940619685e-05
# Sample 170 / 500: p-value 0.0002331563768923503
# Sample 180 / 500: p-value 0.0007052186177776944
# Sample 190 / 500: p-value 0.0035223637472303086
# Sample 200 / 500: p-value 0.0007052186177776944
# Sample 210 / 500: p-value 3.728025964753957e-06
# Sample 220 / 500: p-value 0.0007052186177776944
# Sample 230 / 500: p-value 0.0028186366029831116
# Sample 240 / 500: p-value 0.0007052186177776944
# Sample 250 / 500: p-value 0.0021145367877069476
# Sample 260 / 500: p-value 0.0014100641698067402
# Sample 270 / 500: p-value 0.006333548243956442
# Sample 280 / 500: p-value 0.0007052186177776944
# Sample 290 / 500: p-value 0.0007052186177776944
# Sample 300 / 500: p-value 0.0035223637472303086
# Sample 310 / 500: p-value 0.0021145367877069476
# Sample 320 / 500: p-value 0.0035223637472303086
# Sample 330 / 500: p-value 0.0007052186177776944
# Sample 340 / 500: p-value 0.009839159542405362
# Sample 350 / 500: p-value 0.008438030012867135
# Sample 360 / 500: p-value 0.004928700548726057
# Sample 370 / 500: p-value 0.0027137817093593037
# Sample 380 / 500: p-value 0.0028186366029831116
# Sample 390 / 500: p-value 0.009839159542405362
# Sample 400 / 500: p-value 0.0007052186177776944
# Sample 410 / 500: p-value 0.004225718352000553
# Sample 420 / 500: p-value 0.008438030012867135
# Sample 430 / 500: p-value 0.0007052186177776944
# Sample 440 / 500: p-value 0.0014100641698067402
# Sample 450 / 500: p-value 0.0007052186177776944
# Sample 460 / 500: p-value 0.0007052186177776944
# Sample 470 / 500: p-value 0.0035223637472303086
# Sample 480 / 500: p-value 0.0007052186177776944
# Sample 490 / 500: p-value 0.0007052186177776944
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0007052186177776944
# Sample 10 / 500: p-value 0.0007052186177776944
# Sample 20 / 500: p-value 0.0008866108448579612
# Sample 30 / 500: p-value 0.0028186366029831116
# Sample 40 / 500: p-value 0.0014100641698067402
# Sample 50 / 500: p-value 0.0014100641698067402
# Sample 60 / 500: p-value 0.0001505046668138404
# Sample 70 / 500: p-value 0.0007052186177776944
# Sample 80 / 500: p-value 0.0014100641698067402
# Sample 90 / 500: p-value 0.0035223637472303086
# Sample 100 / 500: p-value 0.0035223637472303086
# Sample 110 / 500: p-value 0.004225718352000553
# Sample 120 / 500: p-value 0.001044824768406251
# Sample 130 / 500: p-value 0.0014100641698067402
# Sample 140 / 500: p-value 0.0007052186177776944
# Sample 150 / 500: p-value 0.0028186366029831116
# Sample 160 / 500: p-value 0.0007052186177776944
# Sample 170 / 500: p-value 0.0014100641698067402
# Sample 180 / 500: p-value 0.0028186366029831116
# Sample 190 / 500: p-value 0.004225718352000553
# Sample 200 / 500: p-value 0.0007052186177776944
# Sample 210 / 500: p-value 0.0007052186177776944
# Sample 220 / 500: p-value 0.0028186366029831116
# Sample 230 / 500: p-value 0.007035414005439635
# Sample 240 / 500: p-value 0.0007052186177776944
# Sample 250 / 500: p-value 0.0014100641698067402
# Sample 260 / 500: p-value 0.0004031405252722607
# Sample 270 / 500: p-value 0.0035223637472303086
# Sample 280 / 500: p-value 0.0035223637472303086
# Sample 290 / 500: p-value 0.0014100641698067402
# Sample 300 / 500: p-value 0.005631310468806453
# Sample 310 / 500: p-value 0.0028186366029831116
# Sample 320 / 500: p-value 0.0007052186177776944
# Sample 330 / 500: p-value 0.0007344642440430855
# Sample 340 / 500: p-value 0.0007052186177776944
# Sample 350 / 500: p-value 0.0021145367877069476
# Sample 360 / 500: p-value 0.0007052186177776944
# Sample 370 / 500: p-value 0.007035414005439635
# Sample 380 / 500: p-value 0.0007052186177776944
# Sample 390 / 500: p-value 0.0007052186177776944
# Sample 400 / 500: p-value 0.0007052186177776944
# Sample 410 / 500: p-value 0.0005672513203907982
# Sample 420 / 500: p-value 0.0007052186177776944
# Sample 430 / 500: p-value 0.0028186366029831116
# Sample 440 / 500: p-value 0.006333548243956442
# Sample 450 / 500: p-value 0.0014100641698067402
# Sample 460 / 500: p-value 0.0014100641698067402
# Sample 470 / 500: p-value 0.0007052186177776944
# Sample 480 / 500: p-value 0.005631310468806453
# Sample 490 / 500: p-value 0.0021145367877069476
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.002114536787698157
# Sample 10 / 500: p-value 0.0008237620684075993
# Sample 20 / 500: p-value 0.0026427048169141362
# Sample 30 / 500: p-value 0.0005289139633310729
# Sample 40 / 500: p-value 3.5366238072006445e-05
# Sample 50 / 500: p-value 0.0015861823243049813
# Sample 60 / 500: p-value 0.006334663627985458
# Sample 70 / 500: p-value 0.003170686444882702
# Sample 80 / 500: p-value 0.002114536787698157
# Sample 90 / 500: p-value 0.0005289139633310729
# Sample 100 / 500: p-value 0.0005289139633310729
# Sample 110 / 500: p-value 0.012117886602439816
# Sample 120 / 500: p-value 0.0026427048169141362
# Sample 130 / 500: p-value 1
# Sample 140 / 500: p-value 0.0005289139633310729
# Sample 150 / 500: p-value 0.003170686444882702
# Sample 160 / 500: p-value 0.0005289139633310729
# Sample 170 / 500: p-value 0.0005289139633310729
# Sample 180 / 500: p-value 0.0005289139633310729
# Sample 190 / 500: p-value 0.0005289139633310729
# Sample 200 / 500: p-value 0.0036984817044686314
# Sample 210 / 500: p-value 0.002114536787698157
# Sample 220 / 500: p-value 0.0015861823243049813
# Sample 230 / 500: p-value 0.0026427048169141362
# Sample 240 / 500: p-value 0.00012371965562875094
# Sample 250 / 500: p-value 0.002974668358092313
# Sample 260 / 500: p-value 0.0010576413937897666
# Sample 270 / 500: p-value 0.005280749601815006
# Sample 280 / 500: p-value 0.0010576413937897666
# Sample 290 / 500: p-value 0.0005289139633310729
# Sample 300 / 500: p-value 0.0005289139633310729
# Sample 310 / 500: p-value 0.0005289139633310729
# Sample 320 / 500: p-value 0.0005289139633310729
# Sample 330 / 500: p-value 1.8646707725670881e-06
# Sample 340 / 500: p-value 0.0015861823243049813
# Sample 350 / 500: p-value 0.0015861823243049813
# Sample 360 / 500: p-value 0.0010576413937897666
# Sample 370 / 500: p-value 0.01054287552465912
# Sample 380 / 500: p-value 1.2296694449113746e-05
# Sample 390 / 500: p-value 0.0010576413937897666
# Sample 400 / 500: p-value 0.00023645920333355584
# Sample 410 / 500: p-value 0.002114536787698157
# Sample 420 / 500: p-value 0.010865242887075487
# Sample 430 / 500: p-value 0.008440257891505177
# Sample 440 / 500: p-value 0.006861341368002348
# Sample 450 / 500: p-value 0.0010576413937897666
# Sample 460 / 500: p-value 0.0010576413937897666
# Sample 470 / 500: p-value 0.0005289139633310729
# Sample 480 / 500: p-value 0.0005289139633310729
# Sample 490 / 500: p-value 0.0005289139633310729
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0070347948577213215
# Sample 10 / 500: p-value 0.0008815232722179457
# Sample 20 / 500: p-value 0.0008815232722179457
# Sample 30 / 500: p-value 0.0017624247681732816
# Sample 40 / 500: p-value 0.007911353124977124
# Sample 50 / 500: p-value 0.0003870416490629973
# Sample 60 / 500: p-value 0.0026427048169126166
# Sample 70 / 500: p-value 0.0044014018878737494
# Sample 80 / 500: p-value 0.0006900510655314734
# Sample 90 / 500: p-value 0.0008815232722179457
# Sample 100 / 500: p-value 0.0017624247681732816
# Sample 110 / 500: p-value 0.0017624247681732816
# Sample 120 / 500: p-value 0.0035223637472136427
# Sample 130 / 500: p-value 0.0017624247681732816
# Sample 140 / 500: p-value 0.0026427048169126166
# Sample 150 / 500: p-value 0.0008815232722179457
# Sample 160 / 500: p-value 0.0008815232722179457
# Sample 170 / 500: p-value 0.0008735515180612192
# Sample 180 / 500: p-value 0.0026427048169126166
# Sample 190 / 500: p-value 0.0008815232722179457
# Sample 200 / 500: p-value 0.0003448953404283361
# Sample 210 / 500: p-value 0.0017624247681732816
# Sample 220 / 500: p-value 0.0017624247681732816
# Sample 230 / 500: p-value 0.0008815232722179457
# Sample 240 / 500: p-value 0.0035223637472136427
# Sample 250 / 500: p-value 0.0017624247681732816
# Sample 260 / 500: p-value 0.0008815232722179457
# Sample 270 / 500: p-value 0.0035223637472136427
# Sample 280 / 500: p-value 0.005386440922045008
# Sample 290 / 500: p-value 0.0003870416490629973
# Sample 300 / 500: p-value 0.0017624247681732816
# Sample 310 / 500: p-value 0.0044014018878737494
# Sample 320 / 500: p-value 0.0008815232722179457
# Sample 330 / 500: p-value 0.0070347948577213215
# Sample 340 / 500: p-value 0.014029943224962342
# Sample 350 / 500: p-value 0.0008815232722179457
# Sample 360 / 500: p-value 0.0061576171145983115
# Sample 370 / 500: p-value 0.0017624247681732816
# Sample 380 / 500: p-value 0.0035223637472136427
# Sample 390 / 500: p-value 1.8646707725765118e-06
# Sample 400 / 500: p-value 0.0061576171145983115
# Sample 410 / 500: p-value 0.0044014018878737494
# Sample 420 / 500: p-value 0.00046689737391648786
# Sample 430 / 500: p-value 0.009662612544642754
# Sample 440 / 500: p-value 0.0017624247681732816
# Sample 450 / 500: p-value 0.0008815232722179457
# Sample 460 / 500: p-value 0.0008815232722179457
# Sample 470 / 500: p-value 0.0026427048169126166
# Sample 480 / 500: p-value 0.0026427048169126166
# Sample 490 / 500: p-value 0.0008815232722179457
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.001057827926660404
# Sample 10 / 500: p-value 0.0021147231889381522
# Sample 20 / 500: p-value 0.001057827926660404
# Sample 30 / 500: p-value 0.0042257183519760185
# Sample 40 / 500: p-value 0.001057827926660404
# Sample 50 / 500: p-value 0.0031706864448774784
# Sample 60 / 500: p-value 0.0010294875197988825
# Sample 70 / 500: p-value 0.0021147231889381522
# Sample 80 / 500: p-value 0.010536388252507667
# Sample 90 / 500: p-value 0.004850609497561308
# Sample 100 / 500: p-value 0.005125823395774965
# Sample 110 / 500: p-value 0.001057827926660404
# Sample 120 / 500: p-value 0.0021147231889381522
# Sample 130 / 500: p-value 0.011584919102306725
# Sample 140 / 500: p-value 0.0031706864448774784
# Sample 150 / 500: p-value 0.001057827926660404
# Sample 160 / 500: p-value 0.001057827926660404
# Sample 170 / 500: p-value 0.001057827926660404
# Sample 180 / 500: p-value 0.001057827926660404
# Sample 190 / 500: p-value 0.008436545632643174
# Sample 200 / 500: p-value 0.0021147231889381522
# Sample 210 / 500: p-value 0.005279819567531275
# Sample 220 / 500: p-value 0.001057827926660404
# Sample 230 / 500: p-value 0.005279819567531275
# Sample 240 / 500: p-value 0.001057827926660404
# Sample 250 / 500: p-value 9.733243555441707e-05
# Sample 260 / 500: p-value 0.0042257183519760185
# Sample 270 / 500: p-value 0.0013508377512700663
# Sample 280 / 500: p-value 0.001057827926660404
# Sample 290 / 500: p-value 0.0021147231889381522
# Sample 300 / 500: p-value 0.007385232551478103
# Sample 310 / 500: p-value 0.0031706864448774784
# Sample 320 / 500: p-value 0.005279819567531275
# Sample 330 / 500: p-value 0.001057827926660404
# Sample 340 / 500: p-value 0.0042257183519760185
# Sample 350 / 500: p-value 0.001057827926660404
# Sample 360 / 500: p-value 0.002119981370585078
# Sample 370 / 500: p-value 0.001057827926660404
# Sample 380 / 500: p-value 0.0021147231889381522
# Sample 390 / 500: p-value 0.0042257183519760185
# Sample 400 / 500: p-value 0.009486930647804141
# Sample 410 / 500: p-value 0.0031706864448774784
# Sample 420 / 500: p-value 0.001057827926660404
# Sample 430 / 500: p-value 0.003351922557687876
# Sample 440 / 500: p-value 0.001057827926660404
# Sample 450 / 500: p-value 0.001057827926660404
# Sample 460 / 500: p-value 3.518920674226415e-05
# Sample 470 / 500: p-value 0.001057827926660404
# Sample 480 / 500: p-value 0.0042257183519760185
# Sample 490 / 500: p-value 0.0021147231889381522
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0017262526177190271
# Sample 10 / 500: p-value 0.0008815232722179457
# Sample 20 / 500: p-value 0.0008815232722179457
# Sample 30 / 500: p-value 0.0017624247681732816
# Sample 40 / 500: p-value 0.0026427048169126166
# Sample 50 / 500: p-value 0.0009061944990441143
# Sample 60 / 500: p-value 0.0044014018878737494
# Sample 70 / 500: p-value 0.0008815232722179457
# Sample 80 / 500: p-value 8.73391045842076e-05
# Sample 90 / 500: p-value 0.0008815232722179457
# Sample 100 / 500: p-value 0.0008815232722179457
# Sample 110 / 500: p-value 0.0017624247681732816
# Sample 120 / 500: p-value 0.005041569997580214
# Sample 130 / 500: p-value 5.634248772708536e-05
# Sample 140 / 500: p-value 0.0044014018878737494
# Sample 150 / 500: p-value 0.0026427048169126166
# Sample 160 / 500: p-value 0.0017624247681732816
# Sample 170 / 500: p-value 0.0008735515180612192
# Sample 180 / 500: p-value 0.0026427048169126166
# Sample 190 / 500: p-value 0.0017624247681732816
# Sample 200 / 500: p-value 0.0017624247681732816
# Sample 210 / 500: p-value 0.0061576171145983115
# Sample 220 / 500: p-value 0.0008815232722179457
# Sample 230 / 500: p-value 0.0008815232722179457
# Sample 240 / 500: p-value 0.0044014018878737494
# Sample 250 / 500: p-value 0.0017624247681732816
# Sample 260 / 500: p-value 0.0008815232722179457
# Sample 270 / 500: p-value 0.0008815232722179457
# Sample 280 / 500: p-value 0.0017624247681732816
# Sample 290 / 500: p-value 0.0008815232722179457
# Sample 300 / 500: p-value 0.0008815232722179457
# Sample 310 / 500: p-value 0.0017624247681732816
# Sample 320 / 500: p-value 0.0008815232722179457
# Sample 330 / 500: p-value 0.004050785013477027
# Sample 340 / 500: p-value 0.0035223637472136427
# Sample 350 / 500: p-value 0.0026427048169126166
# Sample 360 / 500: p-value 0.0017624247681732816
# Sample 370 / 500: p-value 0.0017624247681732816
# Sample 380 / 500: p-value 0.0008815232722179457
# Sample 390 / 500: p-value 0.0008815232722179457
# Sample 400 / 500: p-value 0.0005533869039611525
# Sample 410 / 500: p-value 0.0044014018878737494
# Sample 420 / 500: p-value 3.408924426796072e-05
# Sample 430 / 500: p-value 0.0026427048169126166
# Sample 440 / 500: p-value 0.0017624247681732816
# Sample 450 / 500: p-value 0.0008815232722179457
# Sample 460 / 500: p-value 0.0017624247681732816
# Sample 470 / 500: p-value 0.0001702822204785067
# Sample 480 / 500: p-value 0.0015582500800118044
# Sample 490 / 500: p-value 0.0008815232722179457
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0017624247681732816
# Sample 10 / 500: p-value 0.0004275447884613216
# Sample 20 / 500: p-value 0.0017624247681732816
# Sample 30 / 500: p-value 0.0008815232722179457
# Sample 40 / 500: p-value 9.459593148791629e-05
# Sample 50 / 500: p-value 0.01838185255697681
# Sample 60 / 500: p-value 0.0044014018878737494
# Sample 70 / 500: p-value 0.009662612544642754
# Sample 80 / 500: p-value 0.0006275076822215888
# Sample 90 / 500: p-value 0.0035223637472136427
# Sample 100 / 500: p-value 0.0035223637472136427
# Sample 110 / 500: p-value 0.0017624247681732816
# Sample 120 / 500: p-value 0.009662612544642754
# Sample 130 / 500: p-value 0.0044014018878737494
# Sample 140 / 500: p-value 0.0008815232722179457
# Sample 150 / 500: p-value 0.0017624247681732816
# Sample 160 / 500: p-value 0.00040901355766391565
# Sample 170 / 500: p-value 0.0017624247681732816
# Sample 180 / 500: p-value 0.0009061944990441143
# Sample 190 / 500: p-value 0.0008815232722179457
# Sample 200 / 500: p-value 0.0044014018878737494
# Sample 210 / 500: p-value 0.0017624247681732816
# Sample 220 / 500: p-value 0.0008815232722179457
# Sample 230 / 500: p-value 0.0008815232722179457
# Sample 240 / 500: p-value 0.0017624247681732816
# Sample 250 / 500: p-value 0.0008815232722179457
# Sample 260 / 500: p-value 0.0017624247681732816
# Sample 270 / 500: p-value 7.424532282597567e-05
# Sample 280 / 500: p-value 0.0026427048169126166
# Sample 290 / 500: p-value 0.0008815232722179457
# Sample 300 / 500: p-value 0.0044014018878737494
# Sample 310 / 500: p-value 7.176560702980526e-06
# Sample 320 / 500: p-value 0.0017624247681732816
# Sample 330 / 500: p-value 0.0008815232722179457
# Sample 340 / 500: p-value 0.00021632502082005736
# Sample 350 / 500: p-value 0.0017624247681732816
# Sample 360 / 500: p-value 0.0017624247681732816
# Sample 370 / 500: p-value 0.005279819567536947
# Sample 380 / 500: p-value 0.0017624247681732816
# Sample 390 / 500: p-value 0.0044014018878737494
# Sample 400 / 500: p-value 0.0026427048169126166
# Sample 410 / 500: p-value 0.0044014018878737494
# Sample 420 / 500: p-value 0.0026427048169126166
# Sample 430 / 500: p-value 0.0006336072236423295
# Sample 440 / 500: p-value 0.0044014018878737494
# Sample 450 / 500: p-value 0.0008815232722179457
# Sample 460 / 500: p-value 0.029624938033802648
# Sample 470 / 500: p-value 0.0008815232722179457
# Sample 480 / 500: p-value 0.0008815232722179457
# Sample 490 / 500: p-value 0.0017624247681732816
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0005289139633310729
# Sample 10 / 500: p-value 0.0005289139633310729
# Sample 20 / 500: p-value 0.012117886602439816
# Sample 30 / 500: p-value 0.0010576413937897666
# Sample 40 / 500: p-value 0.003170686444882702
# Sample 50 / 500: p-value 0.0008237620684075993
# Sample 60 / 500: p-value 0.0010576413937897666
# Sample 70 / 500: p-value 1
# Sample 80 / 500: p-value 0.002114536787698157
# Sample 90 / 500: p-value 0.0010576413937897666
# Sample 100 / 500: p-value 0.0015861823243049813
# Sample 110 / 500: p-value 1.2296694449113746e-05
# Sample 120 / 500: p-value 0.0015861823243049813
# Sample 130 / 500: p-value 0.0005289139633310729
# Sample 140 / 500: p-value 0.0009222249755508301
# Sample 150 / 500: p-value 0.014739189321565666
# Sample 160 / 500: p-value 0.0015861823243049813
# Sample 170 / 500: p-value 0.0026427048169141362
# Sample 180 / 500: p-value 0.0036984817044686314
# Sample 190 / 500: p-value 0.005280749601815006
# Sample 200 / 500: p-value 0.0005289139633310729
# Sample 210 / 500: p-value 0.0005289139633310729
# Sample 220 / 500: p-value 0.0010576413937897666
# Sample 230 / 500: p-value 0.0005289139633310729
# Sample 240 / 500: p-value 0.0010576413937897666
# Sample 250 / 500: p-value 0.0015861823243049813
# Sample 260 / 500: p-value 0.0002092710664957838
# Sample 270 / 500: p-value 0.0015861823243049813
# Sample 280 / 500: p-value 0.005280749601815006
# Sample 290 / 500: p-value 0.0026427048169141362
# Sample 300 / 500: p-value 0.002114536787698157
# Sample 310 / 500: p-value 0.0005289139633310729
# Sample 320 / 500: p-value 0.025698027660727374
# Sample 330 / 500: p-value 0.004226090628537098
# Sample 340 / 500: p-value 0.0036984817044686314
# Sample 350 / 500: p-value 0.0005289139633310729
# Sample 360 / 500: p-value 0.0036984817044686314
# Sample 370 / 500: p-value 0.0010576413937897666
# Sample 380 / 500: p-value 0.0036984817044686314
# Sample 390 / 500: p-value 0.05350409912001141
# Sample 400 / 500: p-value 0.0005289139633310729
# Sample 410 / 500: p-value 0.0005289139633310729
# Sample 420 / 500: p-value 0.0015861823243049813
# Sample 430 / 500: p-value 0.002114536787698157
# Sample 440 / 500: p-value 0.0005289139633310729
# Sample 450 / 500: p-value 0.0005289139633310729
# Sample 460 / 500: p-value 0.0010576413937897666
# Sample 470 / 500: p-value 0.0010576413937897666
# Sample 480 / 500: p-value 0.08991045949793124
# Sample 490 / 500: p-value 0.003170686444882702
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0014100641698067402
# Sample 10 / 500: p-value 0.0014100641698067402
# Sample 20 / 500: p-value 0.0077369078847419484
# Sample 30 / 500: p-value 3.730657473673182e-07
# Sample 40 / 500: p-value 0.0007052186177776944
# Sample 50 / 500: p-value 0.0028186366029831116
# Sample 60 / 500: p-value 0.0021145367877069476
# Sample 70 / 500: p-value 0.0007052186177776944
# Sample 80 / 500: p-value 0.007035414005439635
# Sample 90 / 500: p-value 0.0028186366029831116
# Sample 100 / 500: p-value 0.0007052186177776944
# Sample 110 / 500: p-value 0.0028186366029831116
# Sample 120 / 500: p-value 0.0014100641698067402
# Sample 130 / 500: p-value 0.007035414005439635
# Sample 140 / 500: p-value 0.0035223637472303086
# Sample 150 / 500: p-value 0.005631310468806453
# Sample 160 / 500: p-value 0.0021145367877069476
# Sample 170 / 500: p-value 0.004225718352000553
# Sample 180 / 500: p-value 0.006333548243956442
# Sample 190 / 500: p-value 0.0014100641698067402
# Sample 200 / 500: p-value 0.0007052186177776944
# Sample 210 / 500: p-value 0.005631310468806453
# Sample 220 / 500: p-value 0.00011131527799563698
# Sample 230 / 500: p-value 0.0014100641698067402
# Sample 240 / 500: p-value 0.004928700548726057
# Sample 250 / 500: p-value 0.0014100641698067402
# Sample 260 / 500: p-value 0.0014100641698067402
# Sample 270 / 500: p-value 0.0005672513203907982
# Sample 280 / 500: p-value 0.005631310468806453
# Sample 290 / 500: p-value 0.0007052186177776944
# Sample 300 / 500: p-value 0.0014100641698067402
# Sample 310 / 500: p-value 0.01193806898854763
# Sample 320 / 500: p-value 0.0021145367877069476
# Sample 330 / 500: p-value 0.0014100641698067402
# Sample 340 / 500: p-value 0.0007052186177776944
# Sample 350 / 500: p-value 0.0007052186177776944
# Sample 360 / 500: p-value 0.0007052186177776944
# Sample 370 / 500: p-value 0.0077369078847419484
# Sample 380 / 500: p-value 0.0021145367877069476
# Sample 390 / 500: p-value 0.004928700548726057
# Sample 400 / 500: p-value 0.0014100641698067402
# Sample 410 / 500: p-value 0.0035223637472303086
# Sample 420 / 500: p-value 0.0007052186177776944
# Sample 430 / 500: p-value 0.0007344642440430855
# Sample 440 / 500: p-value 1.6756390970134075e-05
# Sample 450 / 500: p-value 0.004225718352000553
# Sample 460 / 500: p-value 0.0007052186177776944
# Sample 470 / 500: p-value 0.0035223637472303086
# Sample 480 / 500: p-value 0.0014100641698067402
# Sample 490 / 500: p-value 0.0007052186177776944
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0070347948577213215
# Sample 10 / 500: p-value 0.0017624247681732816
# Sample 20 / 500: p-value 0.0008815232722179457
# Sample 30 / 500: p-value 0.0008815232722179457
# Sample 40 / 500: p-value 0.0035223637472136427
# Sample 50 / 500: p-value 0.0008815232722179457
# Sample 60 / 500: p-value 0.0011143516127462068
# Sample 70 / 500: p-value 0.005279819567536947
# Sample 80 / 500: p-value 0.0044014018878737494
# Sample 90 / 500: p-value 0.0008815232722179457
# Sample 100 / 500: p-value 0.0035223637472136427
# Sample 110 / 500: p-value 0.0017624247681732816
# Sample 120 / 500: p-value 0.0003870416490629973
# Sample 130 / 500: p-value 0.0017624247681732816
# Sample 140 / 500: p-value 1.3034284593080133e-05
# Sample 150 / 500: p-value 0.0008815232722179457
# Sample 160 / 500: p-value 0.0026427048169126166
# Sample 170 / 500: p-value 0.0008815232722179457
# Sample 180 / 500: p-value 0.0008815232722179457
# Sample 190 / 500: p-value 0.0008815232722179457
# Sample 200 / 500: p-value 0.01577255522891694
# Sample 210 / 500: p-value 0.0026427048169126166
# Sample 220 / 500: p-value 0.0008815232722179457
# Sample 230 / 500: p-value 0.0026427048169126166
# Sample 240 / 500: p-value 0.0017624247681732816
# Sample 250 / 500: p-value 0.0070347948577213215
# Sample 260 / 500: p-value 0.0008815232722179457
# Sample 270 / 500: p-value 0.0017624247681732816
# Sample 280 / 500: p-value 0.0008815232722179457
# Sample 290 / 500: p-value 0.0044014018878737494
# Sample 300 / 500: p-value 0.0017624247681732816
# Sample 310 / 500: p-value 0.0008815232722179457
# Sample 320 / 500: p-value 0.0017624247681732816
# Sample 330 / 500: p-value 0.0017624247681732816
# Sample 340 / 500: p-value 0.0008815232722179457
# Sample 350 / 500: p-value 0.0008815232722179457
# Sample 360 / 500: p-value 0.0008815232722179457
# Sample 370 / 500: p-value 0.000611612551960094
# Sample 380 / 500: p-value 0.0035223637472136427
# Sample 390 / 500: p-value 0.0026427048169126166
# Sample 400 / 500: p-value 0.0017624247681732816
# Sample 410 / 500: p-value 0.0017624247681732816
# Sample 420 / 500: p-value 0.009662612544642754
# Sample 430 / 500: p-value 0.00019227865618777007
# Sample 440 / 500: p-value 0.007911353124977124
# Sample 450 / 500: p-value 0.0017624247681732816
# Sample 460 / 500: p-value 0.0044014018878737494
# Sample 470 / 500: p-value 0.0026427048169126166
# Sample 480 / 500: p-value 0.0035223637472136427
# Sample 490 / 500: p-value 0.0026427048169126166
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0006791636603570854
# Sample 10 / 500: p-value 0.000546377081199111
# Sample 20 / 500: p-value 0.007385232551478103
# Sample 30 / 500: p-value 0.001057827926660404
# Sample 40 / 500: p-value 0.001057827926660404
# Sample 50 / 500: p-value 0.0021147231889381522
# Sample 60 / 500: p-value 0.0031706864448774784
# Sample 70 / 500: p-value 0.0021147231889381522
# Sample 80 / 500: p-value 0.0021147231889381522
# Sample 90 / 500: p-value 0.001057827926660404
# Sample 100 / 500: p-value 0.0021147231889381522
# Sample 110 / 500: p-value 0.0021147231889381522
# Sample 120 / 500: p-value 0.0021147231889381522
# Sample 130 / 500: p-value 0.0021147231889381522
# Sample 140 / 500: p-value 0.001057827926660404
# Sample 150 / 500: p-value 0.0031706864448774784
# Sample 160 / 500: p-value 4.1812204387610066e-05
# Sample 170 / 500: p-value 0.0021147231889381522
# Sample 180 / 500: p-value 0.001057827926660404
# Sample 190 / 500: p-value 0.001057827926660404
# Sample 200 / 500: p-value 0.001057827926660404
# Sample 210 / 500: p-value 0.0012661372294862
# Sample 220 / 500: p-value 0.001057827926660404
# Sample 230 / 500: p-value 0.0042257183519760185
# Sample 240 / 500: p-value 0.0021147231889381522
# Sample 250 / 500: p-value 0.001057827926660404
# Sample 260 / 500: p-value 0.0031706864448774784
# Sample 270 / 500: p-value 6.126686070533307e-05
# Sample 280 / 500: p-value 0.0021147231889381522
# Sample 290 / 500: p-value 0.0031706864448774784
# Sample 300 / 500: p-value 0.001057827926660404
# Sample 310 / 500: p-value 0.0021147231889381522
# Sample 320 / 500: p-value 0.005279819567531275
# Sample 330 / 500: p-value 0.001057827926660404
# Sample 340 / 500: p-value 0.0021147231889381522
# Sample 350 / 500: p-value 0.001057827926660404
# Sample 360 / 500: p-value 0.001057827926660404
# Sample 370 / 500: p-value 0.0017144794382271567
# Sample 380 / 500: p-value 0.006332990748433119
# Sample 390 / 500: p-value 0.001057827926660404
# Sample 400 / 500: p-value 0.0021147231889381522
# Sample 410 / 500: p-value 0.001057827926660404
# Sample 420 / 500: p-value 0.001057827926660404
# Sample 430 / 500: p-value 0.001057827926660404
# Sample 440 / 500: p-value 0.0021147231889381522
# Sample 450 / 500: p-value 0.008501649985320308
# Sample 460 / 500: p-value 0.0005153985006345392
# Sample 470 / 500: p-value 0.0031706864448774784
# Sample 480 / 500: p-value 0.0021147231889381522
# Sample 490 / 500: p-value 0.001057827926660404
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.000528913963331164
# Sample 10 / 500: p-value 1
# Sample 20 / 500: p-value 0.00017630465444372142
# Sample 30 / 500: p-value 0.008991537376629796
# Sample 40 / 500: p-value 0.01904090267992185
# Sample 50 / 500: p-value 0.002997179125543262
# Sample 60 / 500: p-value 0.004231311706649328
# Sample 70 / 500: p-value 0.000528913963331164
# Sample 80 / 500: p-value 0.0017630465444372163
# Sample 90 / 500: p-value 0.00916784203107348
# Sample 100 / 500: p-value 1
# Sample 110 / 500: p-value 0.000528913963331164
# Sample 120 / 500: p-value 0.0014104372355497718
# Sample 130 / 500: p-value 0.0003526093088874429
# Sample 140 / 500: p-value 1
# Sample 150 / 500: p-value 0.0019393511988809325
# Sample 160 / 500: p-value 0.0012341325811060502
# Sample 170 / 500: p-value 0.00017630465444372142
# Sample 180 / 500: p-value 0.002820874471099544
# Sample 190 / 500: p-value 1
# Sample 200 / 500: p-value 1
# Sample 210 / 500: p-value 0.0008815232722186073
# Sample 220 / 500: p-value 0.00863892806774226
# Sample 230 / 500: p-value 0.00017630465444372142
# Sample 240 / 500: p-value 0.01921720733436553
# Sample 250 / 500: p-value 0.023801128349901952
# Sample 260 / 500: p-value 0.001057827926662329
# Sample 270 / 500: p-value 0.00017630465444372142
# Sample 280 / 500: p-value 0.0003526093088874429
# Sample 290 / 500: p-value 1
# Sample 300 / 500: p-value 0.0014104372355497718
# Sample 310 / 500: p-value 0.00793370944996745
# Sample 320 / 500: p-value 0.0012341325811060502
# Sample 330 / 500: p-value 0.01815937940770363
# Sample 340 / 500: p-value 0.0008815232722186073
# Sample 350 / 500: p-value 0.0003526093088874429
# Sample 360 / 500: p-value 0.014809590973272333
# Sample 370 / 500: p-value 0.00017630465444372142
# Sample 380 / 500: p-value 0.006875881523305165
# Sample 390 / 500: p-value 0.00017630465444372142
# Sample 400 / 500: p-value 1
# Sample 410 / 500: p-value 0.07122708039526873
# Sample 420 / 500: p-value 0.004407616361093029
# Sample 430 / 500: p-value 0.0003526093088874429
# Sample 440 / 500: p-value 0.0014104372355497718
# Sample 450 / 500: p-value 0.0012341325811060502
# Sample 460 / 500: p-value 0.01815937940770363
# Sample 470 / 500: p-value 0.02697461212989086
# Sample 480 / 500: p-value 0.00017630465444372142
# Sample 490 / 500: p-value 1
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0017624247681732816
# Sample 10 / 500: p-value 0.0035223637472136427
# Sample 20 / 500: p-value 0.0008815232722179457
# Sample 30 / 500: p-value 0.0026427048169126166
# Sample 40 / 500: p-value 9.459593148791629e-05
# Sample 50 / 500: p-value 0.0017624247681732816
# Sample 60 / 500: p-value 0.0011884074173874597
# Sample 70 / 500: p-value 0.0008815232722179457
# Sample 80 / 500: p-value 0.0008815232722179457
# Sample 90 / 500: p-value 0.000719160147982609
# Sample 100 / 500: p-value 0.0008815232722179457
# Sample 110 / 500: p-value 0.0008815232722179457
# Sample 120 / 500: p-value 0.0035223637472136427
# Sample 130 / 500: p-value 0.0044014018878737494
# Sample 140 / 500: p-value 0.0026427048169126166
# Sample 150 / 500: p-value 0.0035223637472136427
# Sample 160 / 500: p-value 0.0017624247681732816
# Sample 170 / 500: p-value 0.00015614721587095193
# Sample 180 / 500: p-value 0.0017624247681732816
# Sample 190 / 500: p-value 0.0017624247681732816
# Sample 200 / 500: p-value 0.0008815232722179457
# Sample 210 / 500: p-value 0.0017624247681732816
# Sample 220 / 500: p-value 0.0008815232722179457
# Sample 230 / 500: p-value 0.0061576171145983115
# Sample 240 / 500: p-value 0.0044014018878737494
# Sample 250 / 500: p-value 0.0008815232722179457
# Sample 260 / 500: p-value 9.313489621012373e-06
# Sample 270 / 500: p-value 0.0003448953404283361
# Sample 280 / 500: p-value 0.0008815232722179457
# ...
# Sample 250 / 500: p-value 0.0044014018878737494
# Sample 260 / 500: p-value 0.001383714457035357
# Sample 270 / 500: p-value 0.005279819567536947
# Sample 280 / 500: p-value 0.0008815232722179457
# Sample 290 / 500: p-value 0.0026427048169126166
# Sample 300 / 500: p-value 0.005279819567536947
# Sample 310 / 500: p-value 0.0008815232722179457
# Sample 320 / 500: p-value 0.0008815232722179457
# Sample 330 / 500: p-value 0.0017624247681732816
# Sample 340 / 500: p-value 0.0008815232722179457
# Sample 350 / 500: p-value 0.0008815232722179457
# Sample 360 / 500: p-value 0.005279819567536947
# Sample 370 / 500: p-value 0.0008815232722179457
# Sample 380 / 500: p-value 0.007911353124977124
# Sample 390 / 500: p-value 0.0008815232722179457
# Sample 400 / 500: p-value 0.0008815232722179457
# Sample 410 / 500: p-value 0.01838185255697681
# Sample 420 / 500: p-value 6.498760707568183e-05
# Sample 430 / 500: p-value 0.0026427048169126166
# Sample 440 / 500: p-value 7.424532282597567e-05
# Sample 450 / 500: p-value 0.0017624247681732816
# Sample 460 / 500: p-value 0.0008815232722179457
# Sample 470 / 500: p-value 3.408924426796072e-05
# Sample 480 / 500: p-value 0.0008815232722179457
# Sample 490 / 500: p-value 0.011411397997474095
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0008815232722179457
# Sample 10 / 500: p-value 0.0035223637472136427
# Sample 20 / 500: p-value 0.001151088377735351
# Sample 30 / 500: p-value 0.0008815232722179457
# Sample 40 / 500: p-value 0.0026427048169126166
# Sample 50 / 500: p-value 0.0008815232722179457
# Sample 60 / 500: p-value 0.0025755897534157513
# Sample 70 / 500: p-value 0.0026427048169126166
# Sample 80 / 500: p-value 0.0008815232722179457
# Sample 90 / 500: p-value 0.0017624247681732816
# Sample 100 / 500: p-value 0.0006900510655314734
# Sample 110 / 500: p-value 0.0017624247681732816
# Sample 120 / 500: p-value 0.0026427048169126166
# Sample 130 / 500: p-value 0.0008815232722179457
# Sample 140 / 500: p-value 0.0008815232722179457
# Sample 150 / 500: p-value 0.00023288305100915014
# Sample 160 / 500: p-value 0.0008815232722179457
# Sample 170 / 500: p-value 0.0026427048169126166
# Sample 180 / 500: p-value 0.0008815232722179457
# Sample 190 / 500: p-value 0.0008815232722179457
# Sample 200 / 500: p-value 0.0008815232722179457
# Sample 210 / 500: p-value 0.0017624247681732816
# Sample 220 / 500: p-value 0.005279819567536947
# Sample 230 / 500: p-value 0.011411397997474095
# Sample 240 / 500: p-value 0.0017624247681732816
# Sample 250 / 500: p-value 0.0017624247681732816
# Sample 260 / 500: p-value 0.0061576171145983115
# Sample 270 / 500: p-value 0.0026427048169126166
# Sample 280 / 500: p-value 0.0017624247681732816
# Sample 290 / 500: p-value 0.0026427048169126166
# Sample 300 / 500: p-value 0.0035223637472136427
# Sample 310 / 500: p-value 0.0008815232722179457
# Sample 320 / 500: p-value 0.0017624247681732816
# Sample 330 / 500: p-value 0.0017624247681732816
# Sample 340 / 500: p-value 0.0026427048169126166
# Sample 350 / 500: p-value 0.0026427048169126166
# Sample 360 / 500: p-value 0.0035223637472136427
# Sample 370 / 500: p-value 0.0009061944990441143
# Sample 380 / 500: p-value 2.3911062316188077e-05
# Sample 390 / 500: p-value 0.0027991810922484714
# Sample 400 / 500: p-value 0.0035223637472136427
# Sample 410 / 500: p-value 0.0044014018878737494
# Sample 420 / 500: p-value 0.0008815232722179457
# Sample 430 / 500: p-value 0.0017624247681732816
# Sample 440 / 500: p-value 0.0026427048169126166
# Sample 450 / 500: p-value 0.0017624247681732816
# Sample 460 / 500: p-value 0.0008815232722179457
# Sample 470 / 500: p-value 0.0061576171145983115
# Sample 480 / 500: p-value 0.0007553695088293489
# Sample 490 / 500: p-value 0.0008815232722179457
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0007488598157373337
# Sample 10 / 500: p-value 0.0044014018878737494
# Sample 20 / 500: p-value 0.00043461871570260743
# Sample 30 / 500: p-value 0.0017624247681732816
# Sample 40 / 500: p-value 0.0008815232722179457
# Sample 50 / 500: p-value 0.0026427048169126166
# Sample 60 / 500: p-value 0.0017624247681732816
# Sample 70 / 500: p-value 0.0008815232722179457
# Sample 80 / 500: p-value 0.008787292244576663
# Sample 90 / 500: p-value 0.0017624247681732816
# Sample 100 / 500: p-value 0.0017624247681732816
# Sample 110 / 500: p-value 0.0008815232722179457
# Sample 120 / 500: p-value 0.0008815232722179457
# Sample 130 / 500: p-value 0.0008815232722179457
# Sample 140 / 500: p-value 0.00020743045079936503
# Sample 150 / 500: p-value 0.0008815232722179457
# Sample 160 / 500: p-value 0.0017624247681732816
# Sample 170 / 500: p-value 0.0061576171145983115
# Sample 180 / 500: p-value 0.0008815232722179457
# Sample 190 / 500: p-value 0.007911353124977124
# Sample 200 / 500: p-value 0.0025755897534157513
# Sample 210 / 500: p-value 0.0035223637472136427
# Sample 220 / 500: p-value 0.0008815232722179457
# Sample 230 / 500: p-value 0.0017624247681732816
# Sample 240 / 500: p-value 0.0061576171145983115
# Sample 250 / 500: p-value 0.0017624247681732816
# Sample 260 / 500: p-value 9.459593148791629e-05
# Sample 270 / 500: p-value 0.0017262526177190271
# Sample 280 / 500: p-value 0.00050287782205663
# Sample 290 / 500: p-value 0.0025801287494546603
# Sample 300 / 500: p-value 7.424532282597567e-05
# Sample 310 / 500: p-value 0.0017624247681732816
# Sample 320 / 500: p-value 0.0044014018878737494
# Sample 330 / 500: p-value 0.0017624247681732816
# Sample 340 / 500: p-value 0.0035223637472136427
# Sample 350 / 500: p-value 0.0008815232722179457
# Sample 360 / 500: p-value 0.0044014018878737494
# Sample 370 / 500: p-value 0.009662612544642754
# Sample 380 / 500: p-value 0.0017624247681732816
# Sample 390 / 500: p-value 0.0017624247681732816
# Sample 400 / 500: p-value 4.089265235771443e-05
# Sample 410 / 500: p-value 0.00047851655172937417
# Sample 420 / 500: p-value 0.0008815232722179457
# Sample 430 / 500: p-value 0.0008815232722179457
# Sample 440 / 500: p-value 4.089265235771443e-05
# Sample 450 / 500: p-value 0.0008815232722179457
# Sample 460 / 500: p-value 0.00040901355766391565
# Sample 470 / 500: p-value 0.0017624247681732816
# Sample 480 / 500: p-value 0.0061576171145983115
# Sample 490 / 500: p-value 0.0008815232722179457
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0015861823243049813
# Sample 10 / 500: p-value 0.0010576413937897666
# Sample 20 / 500: p-value 0.0005289139633310729
# Sample 30 / 500: p-value 0.006861341368002348
# Sample 40 / 500: p-value 0.0005289139633310729
# Sample 50 / 500: p-value 0.004753513249938459
# Sample 60 / 500: p-value 0.0015861823243049813
# Sample 70 / 500: p-value 0.002114536787698157
# Sample 80 / 500: p-value 0.0005289139633310729
# Sample 90 / 500: p-value 0.0010576413937897666
# Sample 100 / 500: p-value 0.06972938722697254
# Sample 110 / 500: p-value 0.0005289139633310729
# Sample 120 / 500: p-value 0.0010576413937897666
# Sample 130 / 500: p-value 0.0005289139633310729
# Sample 140 / 500: p-value 0.005807799716953163
# Sample 150 / 500: p-value 0.0010576413937897666
# Sample 160 / 500: p-value 0.005807799716953163
# Sample 170 / 500: p-value 0.0005289139633310729
# Sample 180 / 500: p-value 0.01054287552465912
# Sample 190 / 500: p-value 0.0015861823243049813
# Sample 200 / 500: p-value 0.004753513249938459
# Sample 210 / 500: p-value 0.0015861823243049813
# Sample 220 / 500: p-value 0.0015861823243049813
# Sample 230 / 500: p-value 0.0010576413937897666
# Sample 240 / 500: p-value 0.0005289139633310729
# Sample 250 / 500: p-value 0.004658173929572949
# Sample 260 / 500: p-value 0.0010576413937897666
# Sample 270 / 500: p-value 0.0005289139633310729
# Sample 280 / 500: p-value 1
# Sample 290 / 500: p-value 0.014739189321565666
# Sample 300 / 500: p-value 0.0036984817044686314
# Sample 310 / 500: p-value 0.0015861823243049813
# Sample 320 / 500: p-value 0.0015861823243049813
# Sample 330 / 500: p-value 0.0015861823243049813
# Sample 340 / 500: p-value 0.0015861823243049813
# Sample 350 / 500: p-value 0.0005289139633310729
# Sample 360 / 500: p-value 0.003170686444882702
# Sample 370 / 500: p-value 0.0010576413937897666
# Sample 380 / 500: p-value 0.0010576413937897666
# Sample 390 / 500: p-value 0.0005289139633310729
# Sample 400 / 500: p-value 0.0015861823243049813
# Sample 410 / 500: p-value 0.0010576413937897666
# Sample 420 / 500: p-value 0.003170686444882702
# Sample 430 / 500: p-value 0.006334663627985458
# Sample 440 / 500: p-value 0.003170686444882702
# Sample 450 / 500: p-value 0.0005840380463153807
# Sample 460 / 500: p-value 0.0010576413937897666
# Sample 470 / 500: p-value 0.0015861823243049813
# Sample 480 / 500: p-value 0.004226090628537098
# Sample 490 / 500: p-value 0.0015861823243049813
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 5.686451289976325e-05
# Sample 10 / 500: p-value 0.0028186366029831116
# Sample 20 / 500: p-value 0.0014100641698067402
# Sample 30 / 500: p-value 0.0007052186177776944
# Sample 40 / 500: p-value 0.005631310468806453
# Sample 50 / 500: p-value 0.02722828509248674
# Sample 60 / 500: p-value 0.0007052186177776944
# Sample 70 / 500: p-value 0.0007052186177776944
# Sample 80 / 500: p-value 0.02099480856418199
# Sample 90 / 500: p-value 0.0035223637472303086
# Sample 100 / 500: p-value 0.033431947003560746
# Sample 110 / 500: p-value 0.0014100641698067402
# Sample 120 / 500: p-value 0.004928700548726057
# Sample 130 / 500: p-value 0.0028186366029831116
# Sample 140 / 500: p-value 0.0007052186177776944
# Sample 150 / 500: p-value 0.0007052186177776944
# Sample 160 / 500: p-value 0.0014100641698067402
# Sample 170 / 500: p-value 0.0014100641698067402
# Sample 180 / 500: p-value 0.0001505046668138404
# Sample 190 / 500: p-value 0.0035223637472303086
# Sample 200 / 500: p-value 0.0007052186177776944
# Sample 210 / 500: p-value 0.0007052186177776944
# Sample 220 / 500: p-value 0.0007052186177776944
# Sample 230 / 500: p-value 0.0007052186177776944
# Sample 240 / 500: p-value 0.0007052186177776944
# Sample 250 / 500: p-value 0.0014100641698067402
# Sample 260 / 500: p-value 0.0007052186177776944
# Sample 270 / 500: p-value 0.0007052186177776944
# Sample 280 / 500: p-value 0.0007052186177776944
# Sample 290 / 500: p-value 0.0007052186177776944
# Sample 300 / 500: p-value 0.004225718352000553
# Sample 310 / 500: p-value 0.0028186366029831116
# Sample 320 / 500: p-value 0.0014959172389460904
# Sample 330 / 500: p-value 0.0007052186177776944
# Sample 340 / 500: p-value 0.0007052186177776944
# Sample 350 / 500: p-value 0.002299587181195069
# Sample 360 / 500: p-value 0.0016638071685002984
# Sample 370 / 500: p-value 0.0014100641698067402
# Sample 380 / 500: p-value 0.0035223637472303086
# Sample 390 / 500: p-value 0.0007052186177776944
# Sample 400 / 500: p-value 0.0014100641698067402
# Sample 410 / 500: p-value 0.0014100641698067402
# Sample 420 / 500: p-value 0.0007052186177776944
# Sample 430 / 500: p-value 0.0021145367877069476
# Sample 440 / 500: p-value 0.0077369078847419484
# Sample 450 / 500: p-value 0.0035223637472303086
# Sample 460 / 500: p-value 0.004225718352000553
# Sample 470 / 500: p-value 0.0014100641698067402
# Sample 480 / 500: p-value 0.0014100641698067402
# Sample 490 / 500: p-value 0.0014100641698067402
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0017262526177190271
# Sample 10 / 500: p-value 0.0017624247681732816
# Sample 20 / 500: p-value 0.0008815232722179457
# Sample 30 / 500: p-value 0.0017624247681732816
# Sample 40 / 500: p-value 0.0017624247681732816
# Sample 50 / 500: p-value 0.0017624247681732816
# Sample 60 / 500: p-value 0.0008815232722179457
# Sample 70 / 500: p-value 0.0017624247681732816
# Sample 80 / 500: p-value 0.0008815232722179457
# Sample 90 / 500: p-value 0.0008815232722179457
# Sample 100 / 500: p-value 0.0017624247681732816
# Sample 110 / 500: p-value 0.0017624247681732816
# Sample 120 / 500: p-value 0.0008815232722179457
# Sample 130 / 500: p-value 0.0008815232722179457
# Sample 140 / 500: p-value 0.0026427048169126166
# Sample 150 / 500: p-value 0.0070347948577213215
# Sample 160 / 500: p-value 0.0017624247681732816
# Sample 170 / 500: p-value 0.012284863805839978
# Sample 180 / 500: p-value 0.0008815232722179457
# Sample 190 / 500: p-value 0.0008815232722179457
# Sample 200 / 500: p-value 0.0008815232722179457
# Sample 210 / 500: p-value 0.0026427048169126166
# Sample 220 / 500: p-value 0.0026427048169126166
# Sample 230 / 500: p-value 0.0017624247681732816
# Sample 240 / 500: p-value 0.0015503761631097842
# Sample 250 / 500: p-value 0.0044014018878737494
# Sample 260 / 500: p-value 0.0001426195926012631
# Sample 270 / 500: p-value 0.0017624247681732816
# Sample 280 / 500: p-value 0.0026427048169126166
# Sample 290 / 500: p-value 0.0026427048169126166
# Sample 300 / 500: p-value 0.0008815232722179457
# Sample 310 / 500: p-value 0.0017624247681732816
# Sample 320 / 500: p-value 0.0008815232722179457
# Sample 330 / 500: p-value 0.00010568751924621985
# Sample 340 / 500: p-value 0.0035223637472136427
# Sample 350 / 500: p-value 0.0008100283421137795
# Sample 360 / 500: p-value 0.0017624247681732816
# Sample 370 / 500: p-value 0.0044014018878737494
# Sample 380 / 500: p-value 0.00011738909309929078
# Sample 390 / 500: p-value 0.0008815232722179457
# Sample 400 / 500: p-value 0.0001850239560991328
# Sample 410 / 500: p-value 0.0008815232722179457
# Sample 420 / 500: p-value 0.0008815232722179457
# Sample 430 / 500: p-value 0.0017624247681732816
# Sample 440 / 500: p-value 0.0035223637472136427
# Sample 450 / 500: p-value 0.0044014018878737494
# Sample 460 / 500: p-value 0.0008815232722179457
# Sample 470 / 500: p-value 0.0061576171145983115
# Sample 480 / 500: p-value 0.0026427048169126166
# Sample 490 / 500: p-value 0.005279819567536947
# Generate p-value distribution for FDR based on resampling (this might take a while)
# Sample 0 / 500: p-value 0.0007553695088293489
# Sample 10 / 500: p-value 0.0008815232722179457
# Sample 20 / 500: p-value 0.0061576171145983115
# Sample 30 / 500: p-value 0.0017624247681732816
# Sample 40 / 500: p-value 0.0070347948577213215
# Sample 50 / 500: p-value 0.005279819567536947
# Sample 60 / 500: p-value 0.0008815232722179457
# Sample 70 / 500: p-value 0.0008815232722179457
# Sample 80 / 500: p-value 0.0008815232722179457
# Sample 90 / 500: p-value 0.0070347948577213215
# Sample 100 / 500: p-value 0.0008815232722179457
# Sample 110 / 500: p-value 0.0035223637472136427
# Sample 120 / 500: p-value 4.089265235771443e-05
# Sample 130 / 500: p-value 0.0008815232722179457
# Sample 140 / 500: p-value 0.0035223637472136427
# Sample 150 / 500: p-value 0.0008815232722179457
# Sample 160 / 500: p-value 0.0017624247681732816
# Sample 170 / 500: p-value 0.0035223637472136427
# Sample 180 / 500: p-value 0.0017198576344546015
# Sample 190 / 500: p-value 0.009662612544642754
# Sample 200 / 500: p-value 0.0017624247681732816
# Sample 210 / 500: p-value 0.0009298107494496444
# Sample 220 / 500: p-value 0.007911353124977124
# Sample 230 / 500: p-value 0.0017624247681732816
# Sample 240 / 500: p-value 0.0044014018878737494
# Sample 250 / 500: p-value 0.0012249818380550418
# Sample 260 / 500: p-value 0.0026427048169126166
# Sample 270 / 500: p-value 0.002455261463487588
# Sample 280 / 500: p-value 0.0008815232722179457
# Sample 290 / 500: p-value 0.0006615332100688011
# Sample 300 / 500: p-value 0.0026427048169126166
# Sample 310 / 500: p-value 0.0035223637472136427
# Sample 320 / 500: p-value 0.0008815232722179457
# Sample 330 / 500: p-value 0.0008815232722179457
# Sample 340 / 500: p-value 0.0008815232722179457
# Sample 350 / 500: p-value 0.0070347948577213215
# Sample 360 / 500: p-value 0.0008815232722179457
# Sample 370 / 500: p-value 0.0002678108623542104
# Sample 380 / 500: p-value 0.0008100283421137795
# Sample 390 / 500: p-value 0.0026427048169126166
# Sample 400 / 500: p-value 0.0026427048169126166
# Sample 410 / 500: p-value 0.0026427048169126166
# Sample 420 / 500: p-value 0.0026427048169126166
# Sample 430 / 500: p-value 0.0017624247681732816
# Sample 440 / 500: p-value 0.0008815232722179457
# Sample 450 / 500: p-value 0.0017624247681732816
# Sample 460 / 500: p-value 0.0070347948577213215
# Sample 470 / 500: p-value 0.0008815232722179457
# Sample 480 / 500: p-value 0.0044014018878737494
# Sample 490 / 500: p-value 0.0008815232722179457

# %% [markdown]
# There are 12 paths with no GO enrichments

# %%
len([val_sub for key, val in goa_go_dict.items() for _, val_sub in val.items() if val_sub is None])
# Out:
# 12

# %%
sensor_colors = [mpl.colors.to_hex(i) for i in sns.color_palette('Set3')]
effector_colors = ["#A65628", "#F781BF", "#999999",'blue','yellow','red']

# %%
name_dict = e_pcc.df.loc[:,['orf_name','Systematic gene name']].set_index('orf_name').to_dict()['Systematic gene name']

# %%
all_paths
# Out:
# {0: {1: ['coq1', 'grs1-5001', 'yat2', 'mob2-22', 'mob2-19'],
#   2: ['cox12', 'emi1', 'ups1', 'sse1', 'hsf1-848', 'hsc82'],
#   3: ['cox11', 'hap2', 'sdh4', 'sdh2', 'sdh5'],
#   4: ['coa2', 'cto1', 'ycr102w-a', 'cst26', 'hpf1', 'ycr062w'],
#   5: ['gep5', 'yta12', 'agc1', 'pau19', 'sit1', 'ftr1', 'fet3'],
#   6: ['coa2', 'ylr281c', 'saf1', 'ydl159w-a', 'rtg1'],
#   7: ['coq1', 'cbp2', 'ygl114w', 'hsp32', 'ubc6', 'yet2', 'sps18'],
#   8: ['mss2', 'glo1', 'ymr122w-a', 'jjj3', 'edc2', 'inm1'],
#   9: ['gep5', 'lip2', 'lpd1-supp1', 'hom3', 'ydr157w', 'bap2']},
#  1: {1: ['mrc1', 'mcm4-5001', 'yat2', 'mob2-22', 'mob2-19'],
#   2: ['mad2', 'gim5', 'rpl37a', 'rpl42b', 'sse1', 'ydj1', 'hsc82'],
#   3: ['elg1', 'cdc9-5002', 'avt1', 'aep1', 'hap2', 'sdh4', 'sdh2', 'fum1'],
#   4: ['bim1', 'clb4', 'ynl097c-b', 'apt1', 'aro8', 'yer046w-a', 'sip4'],
#   5: ['mrc1', 'rad9', 'sbh2', 'sfc1', 'sit1', 'ftr1', 'fet3'],
#   6: ['ctf4', 'hhf1', 'hht1', 'ydl159w-a', 'rtg1'],
#   7: ['hrp1-4', 'pex1', 'tvp18', 'ubc6', 'yet2', 'sps18'],
#   8: ['hrp1-4', 'dbf4-2', 'cwc2-1', 'nop1-3', 'jjj3', 'edc2', 'inm1'],
#   9: ['mad2',
#    'shp1',
#    'abf1-102-supp1',
#    'oar1',
#    'lpd1-supp1',
#    'hom3',
#    'ydr157w',
#    'bap2']},
#  2: {1: ['arl3', 'mob2-11', 'mob2-14', 'mob2-34'],
#   2: ['cog5', 'cbf1', 'cdc50', 'rpl42b', 'sse1', 'ydj1', 'hsc82'],
#   3: ['cop1-1', 'ent5', 'ycf1', 'ecm29', 'sdh1', 'sdh2', 'fbp1'],
#   4: ['ost3', 'chs2-5006', 'ydl206w', 'tae1', 'cst26', 'hpf1', 'ycr062w'],
#   5: ['cog6', 'pkr1', 'tvp18', 'fit3', 'sit1', 'ftr1', 'fet3'],
#   6: ['gab1-1', 'arv1', 'ecm31', 'ydl159w-a', 'rtg1'],
#   7: ['ost3', 'spc3-4', 'ubc7', 'ubc6', 'yet2', 'sps18'],
#   8: ['cop1-1', 'swa2-supp1', 'gga2', 'ymr122w-a', 'jjj3', 'edc2', 'inm1'],
#   9: ['cop1-1', 'erg4', 'vps20', 'hom6', 'hom2', 'ydr157w', 'bap2']}}

# %%
effectors_df['cluster']=['EC'+str(i+1) for i in effectors_df['effector_cluster'].tolist()]
effectors_df['is_effector']=True

# %%
sensors_df['cluster']=['SC'+str(i) for i in sensors_df['gid'].tolist()]
sensors_df['is_sensor']=True

# %%
pd.concat([effectors_df,sensors_df]).to_csv(snakemake.output.combined_data_for_colors,index=False)

# %%
node_list = [*effectors_df.loc[effectors_df.effector_cluster==0].orf_name.tolist(), 
             *sensors_df.loc[sensors_df.gid!=0].orf_name.tolist(),
             *[item for sublist in [v for key,v in all_paths[0].items()] for item in sublist]]

node_sub = nx.induced_subgraph(e_pcc.graph_gc, node_list)

nx.draw(node_sub)
nx.write_edgelist(nx.induced_subgraph(e_pcc.graph_gc,node_list),snakemake.output.ec1, delimiter=',',data=False)

# %%
node_list = [*effectors_df.loc[effectors_df.effector_cluster==1].orf_name.tolist(), 
             *sensors_df.loc[sensors_df.gid!=0].orf_name.tolist(),
             *[item for sublist in [v for key,v in all_paths[1].items()] for item in sublist]]

node_sub = nx.induced_subgraph(e_pcc.graph_gc, node_list)

nx.draw(node_sub)
nx.write_edgelist(nx.induced_subgraph(e_pcc.graph_gc,node_list),snakemake.output.ec2, delimiter=',',data=False)

# %%
node_list = [*effectors_df.loc[effectors_df.effector_cluster==2].orf_name.tolist(), 
             *sensors_df.loc[sensors_df.gid!=0].orf_name.tolist(),
             *[item for sublist in [v for key,v in all_paths[2].items()] for item in sublist]]

node_sub = nx.induced_subgraph(e_pcc.graph_gc, node_list)

nx.draw(node_sub)
nx.write_edgelist(nx.induced_subgraph(e_pcc.graph_gc,node_list),snakemake.output.ec3, delimiter=',',data=False)

# %%
pos = e_pcc.graph_gc.nodes('pos')

# %%
sensor_color_map = dict(zip(sensors_df.cluster.sort_values().unique()[1:10],sensor_colors[1:10]))
effector_color_map = dict(zip(effectors_df.cluster.sort_values().unique(),effector_colors[:3]))

# %%
sensor_legend_elements = [Line2D([0], [0], marker='^', color='black', label=label,
                              markerfacecolor=color, markersize=10, linestyle="None") for label,color in sensor_color_map.items()] 
effector_legend_elements = [Line2D([0], [0], marker='s', color='black', label=label,
                              markerfacecolor=color, markersize=10, linestyle="None") for label,color in effector_color_map.items()]

# %%
legend_elements = [*effector_legend_elements, 
                   *sensor_legend_elements,
                   *[Line2D([0], [0], marker='o', color='black', label='Other Genes',
                              markerfacecolor='black', markersize=10, linestyle="None"),
                     Line2D([0], [0], marker='o', color='black', label= 'PCC ≥ 0.2',
                              markerfacecolor='black', markersize=0, linestyle="-", alpha=0.5, lw=5)
                    ]]

# %%
fig = plt.figure()
figlegend = plt.figure(figsize=(3,1))
ax = fig.add_subplot(111)
#lines = ax.plot(range(10), plt.randn(10), range(10), plt.randn(10))
ax.axis('off')
lgd = ax.legend(handles=legend_elements,
                handletextpad=0.1, 
                labelspacing=0.4, 
                borderpad=0,
                columnspacing=0.4,
                fontsize=16, 
                ncol=2,
                frameon=False, 
                loc = 'center',
                bbox_to_anchor=(0., 0., 1, 1))
#if snakemake.params['save']:
#fig.savefig(f'../reports/figures/paper_figures_supp/figs6_legend.pdf', dpi=150, pad_inches=0)#, bbox_inches='tight')
